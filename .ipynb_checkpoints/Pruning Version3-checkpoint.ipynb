# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor, plot_tree

from joblib import Parallel, delayed

# %%
from QuadraticConstraintModel import get_leaf_samples

from QuadraticConstraintModel import constrained_optimization_gurobi

from QuadraticConstraintModel import predict_from_COF

from QuadraticConstraintModel import  get_h_from_COF

from QuadraticConstraintModel import get_feature_bounds_from_COF

# %%
def normalized_root_mean_square_error(y_true, y_pred):
    """
    Computes the Normalized Root Mean Square Error (NRMSE) between y_true and y_pred.
    If the range of y_true is zero, it normalizes by the number of samples * outputs.

    Parameters:
        y_true (np.ndarray): Ground truth values, shape (n_samples, n_outputs)
        y_pred (np.ndarray): Predicted values, shape (n_samples, n_outputs)

    Returns:
        float: NRMSE value
    """
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    # Compute RMSE
    rmse = np.sqrt(np.mean((y_true - y_pred) ** 2))
    
    # Compute range
    y_range = np.max(y_true) - np.min(y_true)
    
    if y_range != 0:
        # Normalize by range
        return rmse / y_range
    else:
        # Normalize by n_samples * n_outputs
        n_samples, n_outputs = y_true.shape
        return np.sqrt(np.sum((y_true - y_pred) ** 2) / (n_samples * n_outputs))

# %%
def process_leaf(leaf_id, indices, X_train, y_train, feature_names, optimizer):
    X_leaf = X_train[indices]
    y_leaf = y_train[indices]
    
    # Choose optimizer
    if optimizer == "gurobi":
        M, m0, h = constrained_optimization_gurobi(X_leaf, y_leaf)
    elif optimizer == "gurobi_MSE":
        M, m0, h = constrained_optimization_MSE_gurobi(X_leaf, y_leaf)
    elif optimizer == "least_squares":
        M, m0, h = least_squares_solution(X_leaf, y_leaf)
    elif optimizer == "gurobi_l2":
        # print("Optimizing with L2 regularization")
        M, m0, h = constrained_optimization_regularization_gurobi(X_leaf, y_leaf)
    elif optimizer == "gurobi_MSE_l2":
        # print("Optimizing with MSE L2 regularization")
        M, m0, h = constrained_optimization_MSE_regularization_gurobi(X_leaf, y_leaf)
    else:
        M, m0, h = constrained_optimization(X_leaf, y_leaf)
    
    # Build model info
    model = {
        "leaf_id": leaf_id,
        "CO_Model": {'M': M, 'm0': m0, 'h': h},
        "no_samples": len(indices),
        "indices": indices,
        "bounds": {
            feature_names[i]: (X_leaf[:, i].min(), X_leaf[:, i].max())
            for i in range(X_leaf.shape[1])
        }
    }
    return model


def train_COF_on_leaves_parallel(X_train, y_train, tree, feature_names=None, optimizer="gurobi", n_jobs=-1):
    """
    Train constrained optimization models on tree leaves in parallel.

    Parameters:
        X_train, y_train : np.ndarray
        tree : fitted sklearn tree
        feature_names : list of feature names (optional)
        optimizer : {"gurobi", "CVXPY + SCS"}
        n_jobs : number of parallel workers (-1 = all cores)
    """
    leaf_samples = get_leaf_samples(tree, X_train)

    if feature_names is None:
        feature_names = [f"feature_{i}" for i in range(X_train.shape[1])]

    # Run leaf computations in parallel
    tree_extracted_info = Parallel(n_jobs=n_jobs)(
        delayed(process_leaf)(leaf_id, indices, X_train, y_train, feature_names, optimizer)
        for leaf_id, indices in leaf_samples.items()
    )

    return tree_extracted_info

# %%
# Function to load DataSet
def load_dataset(file_path, num_attributes=2, num_classes=2):
    data = pd.read_csv(file_path)
    X = data.iloc[:, 0 :  num_attributes].values
    y = data.iloc[:,  num_attributes:  num_attributes + num_classes].values
    # y = data.iloc[:, 9:10].values
    return X, y

# %%
sys_name = "navigation_old" #"exp"
n_samples = 500000 #10000
X, y = load_dataset(f"Dataset/{sys_name}/{sys_name}_{n_samples}/data_{sys_name}_{n_samples}.csv",num_attributes=2, num_classes=2)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,  test_size=0.1)
print(f" Shape of X_Training = {X_train.shape} \n Shape of X_Testing = {X_test.shape}")
print(f" Shape of Y_Training = {y_train.shape} \n Shape of Y_Testing = {y_test.shape}")
# Out:
#  Shape of X_Training = (449999, 2)
#  Shape of X_Testing = (50000, 2)
#  Shape of Y_Training = (449999, 2)
#  Shape of Y_Testing = (50000, 2)

# %%
tree = DecisionTreeRegressor()
tree.fit(X_train,y_train)
print(f"Number of leaves: {tree.get_n_leaves()}")
print(f"Total depth of tree: {tree.get_depth()}")
print(f"Number of nodes: {tree.tree_.node_count}")
# Out:
# Number of leaves: 5000
# Total depth of tree: 22
# Number of nodes: 9999

# %%
def train_and_prune_COF_tree_v3(
    X_train, y_train, X_test=None, y_test=None,
    initial_tree_params=None, optimizer="gurobi",
    alpha=1e-6, h_min=0, ignore_h=False, n_jobs=-1
):
    """
    Train a decision tree, build COF models, and prune tree sequentially.
    """

    # -------------------------------
    # 1️⃣ Train initial tree
    # -------------------------------
    if initial_tree_params is None:
        initial_tree_params = {"max_depth": 5}

    tree = DecisionTreeRegressor(**initial_tree_params)
    tree.fit(X_train, y_train)

    # -------------------------------
    # 2️⃣ Build COF models for leaves in parallel
    # -------------------------------
    COF_model_tree = train_COF_on_leaves_parallel(
        X_train, y_train, tree, optimizer=optimizer, n_jobs=n_jobs
    )

    children_left = tree.tree_.children_left
    children_right = tree.tree_.children_right
    leaf_nodes = np.where(children_left == -1)[0]

    leaf_h_dict = {leaf: COF_model_tree[i]['CO_Model']['h'] for i, leaf in enumerate(leaf_nodes)}
    leaf_indices_dict = {leaf: COF_model_tree[i]['indices'] for i, leaf in enumerate(leaf_nodes)}
    leaf_COFS_dict = {leaf: COF_model_tree[i] for i, leaf in enumerate(leaf_nodes)}

    # -------------------------------
    # 3️⃣ Helper function: compute COF
    # -------------------------------
    def compute_h_and_COF(indices):
        """
        Returns h, M, m0 for given indices using optimizer
        """
        if ignore_h:
            return 0, np.zeros((1, X_train.shape[1])), np.zeros(1)

        if optimizer == "gurobi":
            M, m0, h = constrained_optimization_gurobi(X_train[indices], y_train[indices])
        elif optimizer == "gurobi_MSE":
            M, m0, h = constrained_optimization_MSE_gurobi(X_train[indices], y_train[indices])
        else:
            M, m0, h = constrained_optimization(X_train[indices], y_train[indices])

        return h, M, m0

    # -------------------------------
    # 4️⃣ Sequential pruning function
    # -------------------------------
    def prune_node(node):
        left = children_left[node]
        right = children_right[node]

        # Leaf node
        if left == -1 and right == -1:
            return leaf_h_dict[node], 1, leaf_indices_dict[node], False

        # Process children sequentially
        left_cost, left_leaves, left_indices, _ = prune_node(left)
        right_cost, right_leaves, right_indices, _ = prune_node(right)

        combined_indices = np.concatenate([left_indices, right_indices])
        subtree_cost = left_cost + right_cost
        subtree_leaves = left_leaves + right_leaves

        # Compute parent COF
        h_parent, M_parent, m0_parent = compute_h_and_COF(combined_indices)
        prune_cost = h_parent + alpha

        # Decide pruning
        prune_flag = (not ignore_h and h_parent < h_min) or (prune_cost <= subtree_cost)

        if prune_flag:
            # Update tree
            children_left[node] = -1
            children_right[node] = -1

            # Remove child leaves
            for child in [left, right]:
                leaf_COFS_dict.pop(child, None)
                leaf_h_dict.pop(child, None)
                leaf_indices_dict.pop(child, None)

            # Update parent leaf info
            X_leaf = X_train[combined_indices]
            leaf_h_dict[node] = h_parent
            leaf_indices_dict[node] = combined_indices
            leaf_COFS_dict[node] = {
                "leaf_id": node,
                "CO_Model": {"h": h_parent, "M": M_parent, "m0": m0_parent},
                "indices": combined_indices,
                "no_samples": len(combined_indices),
                "bounds": {
                    f"feature_{i}": (X_leaf[:, i].min(), X_leaf[:, i].max())
                    for i in range(X_leaf.shape[1])
                }
            }

            # Debug printing
            print(f"🌳 Pruning triggered at node {node}, h={h_parent:.6f}, alpha={alpha}")
            print(f"➡️ Leaf indices count: {len(combined_indices)}")
            print(f"➡️ M shape: {M_parent.shape}, m0 shape: {m0_parent.shape}")

            return prune_cost, 1, combined_indices, True
        else:
            return subtree_cost, subtree_leaves, combined_indices, False

    # -------------------------------
    # 5️⃣ Stats before pruning
    # -------------------------------
    num_leaves_before = len(leaf_nodes)
    print(f"Before pruning: Leaves={num_leaves_before}")
    print(f"h values before pruning: {list(leaf_h_dict.values())}")

    # -------------------------------
    # 6️⃣ Iterative pruning until stable
    # -------------------------------
    previous_leaf_count = -1
    while True:
        prune_node(0)
        COF_model_tree_pruned = list(leaf_COFS_dict.values())
        current_leaf_count = len(COF_model_tree_pruned)
        print(f"➡️ Current leaf count after step: {current_leaf_count}")
        if current_leaf_count == previous_leaf_count:
            break
        previous_leaf_count = current_leaf_count

    # -------------------------------
    # 7️⃣ Stats after pruning
    # -------------------------------
    print(f"After pruning: Leaves={len(COF_model_tree_pruned)}")
    print(f"h values after pruning: {[leaf['CO_Model']['h'] for leaf in COF_model_tree_pruned]}")

    return tree, COF_model_tree_pruned

# %%
tree, COF_model =train_and_prune_COF_tree_v3(X_train, y_train, X_test=X_test, y_test=y_test, 
                                initial_tree_params={"min_samples_leaf":10}, optimizer="gurobi", 
                                alpha=2, h_min=1, ignore_h=True, n_jobs=-1)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2598283
# Set parameter Username
# Set parameter LicenseID to value 2598283
# Academic license - for non-commercial use only - expires 2025-12-11
# Academic license - for non-commercial use only - expires 2025-12-11
# Set parameter Username
# Set parameter LicenseID to value 2598283
# Set parameter Username
# Set parameter LicenseID to value 2598283
# Set parameter Username
# Set parameter LicenseID to value 2598283
# Set parameter Username
# Set parameter LicenseID to value 2598283
# Set parameter Username
# Set parameter LicenseID to value 2598283
# Academic license - for non-commercial use only - expires 2025-12-11
# Set parameter Username
# Set parameter LicenseID to value 2598283
# Academic license - for non-commercial use only - expires 2025-12-11
# Academic license - for non-commercial use only - expires 2025-12-11
# Academic license - for non-commercial use only - expires 2025-12-11
# Academic license - for non-commercial use only - expires 2025-12-11
# Set parameter Username
# Set parameter LicenseID to value 2598283
#
, 3.9011109998192652, 4.0239584422123365, 7.233967279801333, 5.438027166720391, 5.337570061792321, 1.7005742976465956, 2.510449329666341, 4.456657660830333, 4.718189494272566, 5.381584798336514, 2.4351626934718342, 6.042385903863118, 2.495508531290094, 12.288641126591251, 3.7797414694936458, 5.582297943372304, 2.8735490949668643, 6.482402858985188, 7.721823091083568, 8.098088146193465, 7.249226300764181, 2.552617766402622, 4.263898902843222, 6.473830594237676, 7.9008108235063, 8.4888230135628, 6.2942667798528324, 5.69059828636482, 2.9767112434483454, 6.598769956684263, 5.146168970300291, 5.288695980889415, 7.36 ...
# 🌳 Pruning triggered at node 8, h=0.000000, alpha=2
# ➡️ Leaf indices count: 24
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 7, h=0.000000, alpha=2
# ➡️ Leaf indices count: 42
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 12, h=0.000000, alpha=2
# ➡️ Leaf indices count: 31
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 6, h=0.000000, alpha=2
# ➡️ Leaf indices count: 73
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 17, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 15, h=0.000000, alpha=2
# ➡️ Leaf indices count: 39
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 5, h=0.000000, alpha=2
# ➡️ Leaf indices count: 112
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 4, h=0.000000, alpha=2
# ➡️ Leaf indices count: 122
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 24, h=0.000000, alpha=2
# ➡️ Leaf indices count: 34
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22, h=0.000000, alpha=2
# ➡️ Leaf indices count: 52
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 35, h=0.000000, alpha=2
# ➡️ Leaf indices count: 26
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 38, h=0.000000, alpha=2
# ➡️ Leaf indices count: 33
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 34, h=0.000000, alpha=2
# ➡️ Leaf indices count: 59
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 33, h=0.000000, alpha=2
# ➡️ Leaf indices count: 74
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 56, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 55, h=0.000000, alpha=2
# ➡️ Leaf indices count: 42
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 62, h=0.000000, alpha=2
# ➡️ Leaf indices count: 26
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 61, h=0.000000, alpha=2
# ➡️ Leaf indices count: 44
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 67, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 78, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 77, h=0.000000, alpha=2
# ➡️ Leaf indices count: 36
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 75, h=0.000000, alpha=2
# ➡️ Leaf indices count: 54
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 74, h=0.000000, alpha=2
# ➡️ Leaf indices count: 65
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 87, h=0.000000, alpha=2
# ➡️ Leaf indices count: 30
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 85, h=0.000000, alpha=2
# ➡️ Leaf indices count: 49
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 92, h=0.000000, alpha=2
# ➡️ Leaf indices count: 26
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 90, h=0.000000, alpha=2
# ➡️ Leaf indices count: 36
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 84, h=0.000000, alpha=2
# ➡️ Leaf indices count: 85
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 101, h=0.000000, alpha=2
# ➡️ Leaf indices count: 26
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 100, h=0.000000, alpha=2
# ➡️ Leaf indices count: 36
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 112, h=0.000000, alpha=2
# ➡️ Leaf indices count: 21
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 115, h=0.000000, alpha=2
# ➡️ Leaf indices count: 26
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 111, h=0.000000, alpha=2
# ➡️ Leaf indices count: 47
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 109, h=0.000000, alpha=2
# ➡️ Leaf indices count: 63
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 108, h=0.000000, alpha=2
# ➡️ Leaf indices count: 73
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 106, h=0.000000, alpha=2
# ➡️ Leaf indices count: 89
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 125, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 123, h=0.000000, alpha=2
# ➡️ Leaf indices count: 43
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 128, h=0.000000, alpha=2
# ➡️ Leaf indices count: 38
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 122, h=0.000000, alpha=2
# ➡️ Leaf indices count: 81
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 120, h=0.000000, alpha=2
# ➡️ Leaf indices count: 92
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 131, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 119, h=0.000000, alpha=2
# ➡️ Leaf indices count: 115
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 105, h=0.000000, alpha=2
# ➡️ Leaf indices count: 204
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 99, h=0.000000, alpha=2
# ➡️ Leaf indices count: 240
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 97, h=0.000000, alpha=2
# ➡️ Leaf indices count: 251
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 95, h=0.000000, alpha=2
# ➡️ Leaf indices count: 262
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 83, h=0.000000, alpha=2
# ➡️ Leaf indices count: 347
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 73, h=0.000000, alpha=2
# ➡️ Leaf indices count: 412
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 72, h=0.000000, alpha=2
# ➡️ Leaf indices count: 424
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 135, h=0.000000, alpha=2
# ➡️ Leaf indices count: 21
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 71, h=0.000000, alpha=2
# ➡️ Leaf indices count: 445
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 139, h=0.000000, alpha=2
# ➡️ Leaf indices count: 29
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 144, h=0.000000, alpha=2
# ➡️ Leaf indices count: 30
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 149, h=0.000000, alpha=2
# ➡️ Leaf indices count: 35
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 148, h=0.000000, alpha=2
# ➡️ Leaf indices count: 45
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 147, h=0.000000, alpha=2
# ➡️ Leaf indices count: 64
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 143, h=0.000000, alpha=2
# ➡️ Leaf indices count: 94
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 142, h=0.000000, alpha=2
# ➡️ Leaf indices count: 110
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 138, h=0.000000, alpha=2
# ➡️ Leaf indices count: 139
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 70, h=0.000000, alpha=2
# ➡️ Leaf indices count: 584
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 66, h=0.000000, alpha=2
# ➡️ Leaf indices count: 609
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 60, h=0.000000, alpha=2
# ➡️ Leaf indices count: 653
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 54, h=0.000000, alpha=2
# ➡️ Leaf indices count: 695
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 158, h=0.000000, alpha=2
# ➡️ Leaf indices count: 21
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 162, h=0.000000, alpha=2
# ➡️ Leaf indices count: 30
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 166, h=0.000000, alpha=2
# ➡️ Leaf indices count: 31
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 170, h=0.000000, alpha=2
# ➡️ Leaf indices count: 24
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 173, h=0.000000, alpha=2
# ➡️ Leaf indices count: 29
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 169, h=0.000000, alpha=2
# ➡️ Leaf indices count: 53
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 165, h=0.000000, alpha=2
# ➡️ Leaf indices count: 84
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 161, h=0.000000, alpha=2
# ➡️ Leaf indices count: 114
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 157, h=0.000000, alpha=2
# ➡️ Leaf indices count: 135
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 155, h=0.000000, alpha=2
# ➡️ Leaf indices count: 146
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 53, h=0.000000, alpha=2
# ➡️ Leaf indices count: 841
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 181, h=0.000000, alpha=2
# ➡️ Leaf indices count: 28
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 180, h=0.000000, alpha=2
# ➡️ Leaf indices count: 38
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 179, h=0.000000, alpha=2
# ➡️ Leaf indices count: 53
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 187, h=0.000000, alpha=2
# ➡️ Leaf indices count: 31
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 186, h=0.000000, alpha=2
# ➡️ Leaf indices count: 48
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 178, h=0.000000, alpha=2
# ➡️ Leaf indices count: 101
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 200, h=0.000000, alpha=2
# ➡️ Leaf indices count: 22
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 198, h=0.000000, alpha=2
# ➡️ Leaf indices count: 41
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 196, h=0.000000, alpha=2
# ➡️ Leaf indices count: 53
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 195, h=0.000000, alpha=2
# ➡️ Leaf indices count: 71
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 193, h=0.000000, alpha=2
# ➡️ Leaf indices count: 81
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 191, h=0.000000, alpha=2
# ➡️ Leaf indices count: 93
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 177, h=0.000000, alpha=2
# ➡️ Leaf indices count: 194
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 207, h=0.000000, alpha=2
# ➡️ Leaf indices count: 22
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 205, h=0.000000, alpha=2
# ➡️ Leaf indices count: 40
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 216, h=0.000000, alpha=2
# ➡️ Leaf indices count: 26
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 221, h=0.000000, alpha=2
# ➡️ Leaf indices count: 29
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 219, h=0.000000, alpha=2
# ➡️ Leaf indices count: 45
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 215, h=0.000000, alpha=2
# ➡️ Leaf indices count: 71
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 213, h=0.000000, alpha=2
# ➡️ Leaf indices count: 85
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 211, h=0.000000, alpha=2
# ➡️ Leaf indices count: 96
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 210, h=0.000000, alpha=2
# ➡️ Leaf indices count: 110
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 204, h=0.000000, alpha=2
# ➡️ Leaf indices count: 150
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 176, h=0.000000, alpha=2
# ➡️ Leaf indices count: 344
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 52, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1185
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 225, h=0.000000, alpha=2
# ➡️ Leaf indices count: 22
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 51, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1207
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 231, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 230, h=0.000000, alpha=2
# ➡️ Leaf indices count: 42
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 228, h=0.000000, alpha=2
# ➡️ Leaf indices count: 52
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 50, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1259
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 237, h=0.000000, alpha=2
# ➡️ Leaf indices count: 28
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 240, h=0.000000, alpha=2
# ➡️ Leaf indices count: 24
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 236, h=0.000000, alpha=2
# ➡️ Leaf indices count: 52
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 247, h=0.000000, alpha=2
# ➡️ Leaf indices count: 32
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 245, h=0.000000, alpha=2
# ➡️ Leaf indices count: 42
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 243, h=0.000000, alpha=2
# ➡️ Leaf indices count: 53
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 235, h=0.000000, alpha=2
# ➡️ Leaf indices count: 105
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 49, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1364
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 48, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1383
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 47, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1394
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 253, h=0.000000, alpha=2
# ➡️ Leaf indices count: 30
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 252, h=0.000000, alpha=2
# ➡️ Leaf indices count: 47
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 46, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1441
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 261, h=0.000000, alpha=2
# ➡️ Leaf indices count: 20
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 260, h=0.000000, alpha=2
# ➡️ Leaf indices count: 30
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 267, h=0.000000, alpha=2
# ➡️ Leaf indices count: 34
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 270, h=0.000000, alpha=2
# ➡️ Leaf indices count: 20
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 266, h=0.000000, alpha=2
# ➡️ Leaf indices count: 54
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 275, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 274, h=0.000000, alpha=2
# ➡️ Leaf indices count: 40
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 284, h=0.000000, alpha=2
# ➡️ Leaf indices count: 35
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 283, h=0.000000, alpha=2
# ➡️ Leaf indices count: 52
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 281, h=0.000000, alpha=2
# ➡️ Leaf indices count: 69
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 279, h=0.000000, alpha=2
# ➡️ Leaf indices count: 83
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 273, h=0.000000, alpha=2
# ➡️ Leaf indices count: 123
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 265, h=0.000000, alpha=2
# ➡️ Leaf indices count: 177
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 259, h=0.000000, alpha=2
# ➡️ Leaf indices count: 207
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 257, h=0.000000, alpha=2
# ➡️ Leaf indices count: 218
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 45, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1659
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 289, h=0.000000, alpha=2
# ➡️ Leaf indices count: 30
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 298, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 297, h=0.000000, alpha=2
# ➡️ Leaf indices count: 41
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 296, h=0.000000, alpha=2
# ➡️ Leaf indices count: 55
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 295, h=0.000000, alpha=2
# ➡️ Leaf indices count: 71
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 304, h=0.000000, alpha=2
# ➡️ Leaf indices count: 32
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 294, h=0.000000, alpha=2
# ➡️ Leaf indices count: 103
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 292, h=0.000000, alpha=2
# ➡️ Leaf indices count: 119
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 288, h=0.000000, alpha=2
# ➡️ Leaf indices count: 149
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 44, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1808
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 314, h=0.000000, alpha=2
# ➡️ Leaf indices count: 37
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 312, h=0.000000, alpha=2
# ➡️ Leaf indices count: 55
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 317, h=0.000000, alpha=2
# ➡️ Leaf indices count: 22
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 311, h=0.000000, alpha=2
# ➡️ Leaf indices count: 77
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 309, h=0.000000, alpha=2
# ➡️ Leaf indices count: 95
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 307, h=0.000000, alpha=2
# ➡️ Leaf indices count: 113
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 43, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1921
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 326, h=0.000000, alpha=2
# ➡️ Leaf indices count: 28
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 329, h=0.000000, alpha=2
# ➡️ Leaf indices count: 30
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 325, h=0.000000, alpha=2
# ➡️ Leaf indices count: 58
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 323, h=0.000000, alpha=2
# ➡️ Leaf indices count: 68
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 321, h=0.000000, alpha=2
# ➡️ Leaf indices count: 84
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 334, h=0.000000, alpha=2
# ➡️ Leaf indices count: 33
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 332, h=0.000000, alpha=2
# ➡️ Leaf indices count: 50
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 320, h=0.000000, alpha=2
# ➡️ Leaf indices count: 134
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 42, h=0.000000, alpha=2
# ➡️ Leaf indices count: 2055
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 32, h=0.000000, alpha=2
# ➡️ Leaf indices count: 2129
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 340, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 343, h=0.000000, alpha=2
# ➡️ Leaf indices count: 31
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 339, h=0.000000, alpha=2
# ➡️ Leaf indices count: 54
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 337, h=0.000000, alpha=2
# ➡️ Leaf indices count: 73
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 31, h=0.000000, alpha=2
# ➡️ Leaf indices count: 2202
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 29, h=0.000000, alpha=2
# ➡️ Leaf indices count: 2212
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 27, h=0.000000, alpha=2
# ➡️ Leaf indices count: 2227
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 21, h=0.000000, alpha=2
# ➡️ Leaf indices count: 2279
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 3, h=0.000000, alpha=2
# ➡️ Leaf indices count: 2401
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 2, h=0.000000, alpha=2
# ➡️ Leaf indices count: 2411
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 348, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 352, h=0.000000, alpha=2
# ➡️ Leaf indices count: 22
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 360, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 365, h=0.000000, alpha=2
# ➡️ Leaf indices count: 24
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 363, h=0.000000, alpha=2
# ➡️ Leaf indices count: 36
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 359, h=0.000000, alpha=2
# ➡️ Leaf indices count: 59
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 368, h=0.000000, alpha=2
# ➡️ Leaf indices count: 20
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 358, h=0.000000, alpha=2
# ➡️ Leaf indices count: 79
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 373, h=0.000000, alpha=2
# ➡️ Leaf indices count: 21
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 371, h=0.000000, alpha=2
# ➡️ Leaf indices count: 33
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 357, h=0.000000, alpha=2
# ➡️ Leaf indices count: 112
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 356, h=0.000000, alpha=2
# ➡️ Leaf indices count: 125
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 381, h=0.000000, alpha=2
# ➡️ Leaf indices count: 29
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 379, h=0.000000, alpha=2
# ➡️ Leaf indices count: 39
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 378, h=0.000000, alpha=2
# ➡️ Leaf indices count: 52
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 389, h=0.000000, alpha=2
# ➡️ Leaf indices count: 30
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 388, h=0.000000, alpha=2
# ➡️ Leaf indices count: 45
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 397, h=0.000000, alpha=2
# ➡️ Leaf indices count: 20
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 396, h=0.000000, alpha=2
# ➡️ Leaf indices count: 31
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 394, h=0.000000, alpha=2
# ➡️ Leaf indices count: 46
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 393, h=0.000000, alpha=2
# ➡️ Leaf indices count: 63
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 387, h=0.000000, alpha=2
# ➡️ Leaf indices count: 108
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 385, h=0.000000, alpha=2
# ➡️ Leaf indices count: 119
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 377, h=0.000000, alpha=2
# ➡️ Leaf indices count: 171
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 355, h=0.000000, alpha=2
# ➡️ Leaf indices count: 296
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 351, h=0.000000, alpha=2
# ➡️ Leaf indices count: 318
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 347, h=0.000000, alpha=2
# ➡️ Leaf indices count: 343
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 1, h=0.000000, alpha=2
# ➡️ Leaf indices count: 2754
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 410, h=0.000000, alpha=2
# ➡️ Leaf indices count: 24
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 408, h=0.000000, alpha=2
# ➡️ Leaf indices count: 40
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 418, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 417, h=0.000000, alpha=2
# ➡️ Leaf indices count: 36
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 425, h=0.000000, alpha=2
# ➡️ Leaf indices count: 27
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 424, h=0.000000, alpha=2
# ➡️ Leaf indices count: 42
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 423, h=0.000000, alpha=2
# ➡️ Leaf indices count: 61
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 432, h=0.000000, alpha=2
# ➡️ Leaf indices count: 24
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 430, h=0.000000, alpha=2
# ➡️ Leaf indices count: 34
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 422, h=0.000000, alpha=2
# ➡️ Leaf indices count: 95
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 416, h=0.000000, alpha=2
# ➡️ Leaf indices count: 131
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 414, h=0.000000, alpha=2
# ➡️ Leaf indices count: 143
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 413, h=0.000000, alpha=2
# ➡️ Leaf indices count: 154
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 407, h=0.000000, alpha=2
# ➡️ Leaf indices count: 194
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 437, h=0.000000, alpha=2
# ➡️ Leaf indices count: 24
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 440, h=0.000000, alpha=2
# ➡️ Leaf indices count: 22
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 436, h=0.000000, alpha=2
# ➡️ Leaf indices count: 46
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 406, h=0.000000, alpha=2
# ➡️ Leaf indices count: 240
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 405, h=0.000000, alpha=2
# ➡️ Leaf indices count: 257
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 444, h=0.000000, alpha=2
# ➡️ Leaf indices count: 20
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 404, h=0.000000, alpha=2
# ➡️ Leaf indices count: 277
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 449, h=0.000000, alpha=2
# ➡️ Leaf indices count: 27
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 447, h=0.000000, alpha=2
# ➡️ Leaf indices count: 38
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 403, h=0.000000, alpha=2
# ➡️ Leaf indices count: 315
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 453, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 462, h=0.000000, alpha=2
# ➡️ Leaf indices count: 29
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 460, h=0.000000, alpha=2
# ➡️ Leaf indices count: 47
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 468, h=0.000000, alpha=2
# ➡️ Leaf indices count: 24
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 472, h=0.000000, alpha=2
# ➡️ Leaf indices count: 26
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 487, h=0.000000, alpha=2
# ➡️ Leaf indices count: 33
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 485, h=0.000000, alpha=2
# ➡️ Leaf indices count: 44
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 484, h=0.000000, alpha=2
# ➡️ Leaf indices count: 60
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 483, h=0.000000, alpha=2
# ➡️ Leaf indices count: 73
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 482, h=0.000000, alpha=2
# ➡️ Leaf indices count: 83
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 494, h=0.000000, alpha=2
# ➡️ Leaf indices count: 26
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 493, h=0.000000, alpha=2
# ➡️ Leaf indices count: 42
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 481, h=0.000000, alpha=2
# ➡️ Leaf indices count: 125
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 480, h=0.000000, alpha=2
# ➡️ Leaf indices count: 135
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 479, h=0.000000, alpha=2
# ➡️ Leaf indices count: 146
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 502, h=0.000000, alpha=2
# ➡️ Leaf indices count: 22
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 500, h=0.000000, alpha=2
# ➡️ Leaf indices count: 37
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 478, h=0.000000, alpha=2
# ➡️ Leaf indices count: 183
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 507, h=0.000000, alpha=2
# ➡️ Leaf indices count: 29
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 506, h=0.000000, alpha=2
# ➡️ Leaf indices count: 42
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 513, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 511, h=0.000000, alpha=2
# ➡️ Leaf indices count: 36
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 505, h=0.000000, alpha=2
# ➡️ Leaf indices count: 78
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 477, h=0.000000, alpha=2
# ➡️ Leaf indices count: 261
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 475, h=0.000000, alpha=2
# ➡️ Leaf indices count: 271
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 471, h=0.000000, alpha=2
# ➡️ Leaf indices count: 297
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 467, h=0.000000, alpha=2
# ➡️ Leaf indices count: 321
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 528, h=0.000000, alpha=2
# ➡️ Leaf indices count: 35
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 526, h=0.000000, alpha=2
# ➡️ Leaf indices count: 47
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 524, h=0.000000, alpha=2
# ➡️ Leaf indices count: 59
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 523, h=0.000000, alpha=2
# ➡️ Leaf indices count: 72
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 522, h=0.000000, alpha=2
# ➡️ Leaf indices count: 86
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 521, h=0.000000, alpha=2
# ➡️ Leaf indices count: 96
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 520, h=0.000000, alpha=2
# ➡️ Leaf indices count: 113
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 537, h=0.000000, alpha=2
# ➡️ Leaf indices count: 27
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 554, h=0.000000, alpha=2
# ➡️ Leaf indices count: 22
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 558, h=0.000000, alpha=2
# ➡️ Leaf indices count: 26
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 557, h=0.000000, alpha=2
# ➡️ Leaf indices count: 36
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 553, h=0.000000, alpha=2
# ➡️ Leaf indices count: 58
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 551, h=0.000000, alpha=2
# ➡️ Leaf indices count: 68
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 549, h=0.000000, alpha=2
# ➡️ Leaf indices count: 87
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 547, h=0.000000, alpha=2
# ➡️ Leaf indices count: 98
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 563, h=0.000000, alpha=2
# ➡️ Leaf indices count: 29
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 567, h=0.000000, alpha=2
# ➡️ Leaf indices count: 30
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 571, h=0.000000, alpha=2
# ➡️ Leaf indices count: 27
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 575, h=0.000000, alpha=2
# ➡️ Leaf indices count: 26
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 578, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 574, h=0.000000, alpha=2
# ➡️ Leaf indices count: 49
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 570, h=0.000000, alpha=2
# ➡️ Leaf indices count: 76
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 566, h=0.000000, alpha=2
# ➡️ Leaf indices count: 106
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 562, h=0.000000, alpha=2
# ➡️ Leaf indices count: 135
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 546, h=0.000000, alpha=2
# ➡️ Leaf indices count: 233
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 544, h=0.000000, alpha=2
# ➡️ Leaf indices count: 245
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 542, h=0.000000, alpha=2
# ➡️ Leaf indices count: 257
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 540, h=0.000000, alpha=2
# ➡️ Leaf indices count: 270
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 536, h=0.000000, alpha=2
# ➡️ Leaf indices count: 297
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 591, h=0.000000, alpha=2
# ➡️ Leaf indices count: 20
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 590, h=0.000000, alpha=2
# ➡️ Leaf indices count: 32
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 597, h=0.000000, alpha=2
# ➡️ Leaf indices count: 28
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 595, h=0.000000, alpha=2
# ➡️ Leaf indices count: 40
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 589, h=0.000000, alpha=2
# ➡️ Leaf indices count: 72
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 588, h=0.000000, alpha=2
# ➡️ Leaf indices count: 90
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 602, h=0.000000, alpha=2
# ➡️ Leaf indices count: 22
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 605, h=0.000000, alpha=2
# ➡️ Leaf indices count: 29
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 601, h=0.000000, alpha=2
# ➡️ Leaf indices count: 51
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 587, h=0.000000, alpha=2
# ➡️ Leaf indices count: 141
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 613, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 611, h=0.000000, alpha=2
# ➡️ Leaf indices count: 38
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 609, h=0.000000, alpha=2
# ➡️ Leaf indices count: 56
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 624, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 622, h=0.000000, alpha=2
# ➡️ Leaf indices count: 36
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 628, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 627, h=0.000000, alpha=2
# ➡️ Leaf indices count: 37
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 621, h=0.000000, alpha=2
# ➡️ Leaf indices count: 73
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 634, h=0.000000, alpha=2
# ➡️ Leaf indices count: 34
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 632, h=0.000000, alpha=2
# ➡️ Leaf indices count: 44
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 620, h=0.000000, alpha=2
# ➡️ Leaf indices count: 117
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 618, h=0.000000, alpha=2
# ➡️ Leaf indices count: 129
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 616, h=0.000000, alpha=2
# ➡️ Leaf indices count: 148
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 608, h=0.000000, alpha=2
# ➡️ Leaf indices count: 204
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 586, h=0.000000, alpha=2
# ➡️ Leaf indices count: 345
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 641, h=0.000000, alpha=2
# ➡️ Leaf indices count: 20
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 640, h=0.000000, alpha=2
# ➡️ Leaf indices count: 32
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 645, h=0.000000, alpha=2
# ➡️ Leaf indices count: 24
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 639, h=0.000000, alpha=2
# ➡️ Leaf indices count: 56
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 638, h=0.000000, alpha=2
# ➡️ Leaf indices count: 69
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 637, h=0.000000, alpha=2
# ➡️ Leaf indices count: 79
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 585, h=0.000000, alpha=2
# ➡️ Leaf indices count: 424
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 654, h=0.000000, alpha=2
# ➡️ Leaf indices count: 24
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 653, h=0.000000, alpha=2
# ➡️ Leaf indices count: 39
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 651, h=0.000000, alpha=2
# ➡️ Leaf indices count: 57
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 664, h=0.000000, alpha=2
# ➡️ Leaf indices count: 28
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 668, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 672, h=0.000000, alpha=2
# ➡️ Leaf indices count: 29
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 675, h=0.000000, alpha=2
# ➡️ Leaf indices count: 38
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 671, h=0.000000, alpha=2
# ➡️ Leaf indices count: 67
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 667, h=0.000000, alpha=2
# ➡️ Leaf indices count: 90
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 663, h=0.000000, alpha=2
# ➡️ Leaf indices count: 118
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 678, h=0.000000, alpha=2
# ➡️ Leaf indices count: 37
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 662, h=0.000000, alpha=2
# ➡️ Leaf indices count: 155
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 682, h=0.000000, alpha=2
# ➡️ Leaf indices count: 28
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 681, h=0.000000, alpha=2
# ➡️ Leaf indices count: 41
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 661, h=0.000000, alpha=2
# ➡️ Leaf indices count: 196
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 659, h=0.000000, alpha=2
# ➡️ Leaf indices count: 206
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 686, h=0.000000, alpha=2
# ➡️ Leaf indices count: 22
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 658, h=0.000000, alpha=2
# ➡️ Leaf indices count: 228
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 650, h=0.000000, alpha=2
# ➡️ Leaf indices count: 285
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 584, h=0.000000, alpha=2
# ➡️ Leaf indices count: 709
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 583, h=0.000000, alpha=2
# ➡️ Leaf indices count: 719
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 692, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 690, h=0.000000, alpha=2
# ➡️ Leaf indices count: 33
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 582, h=0.000000, alpha=2
# ➡️ Leaf indices count: 752
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 696, h=0.000000, alpha=2
# ➡️ Leaf indices count: 31
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 700, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 712, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 710, h=0.000000, alpha=2
# ➡️ Leaf indices count: 37
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 720, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 718, h=0.000000, alpha=2
# ➡️ Leaf indices count: 37
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 723, h=0.000000, alpha=2
# ➡️ Leaf indices count: 29
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 717, h=0.000000, alpha=2
# ➡️ Leaf indices count: 66
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 716, h=0.000000, alpha=2
# ➡️ Leaf indices count: 83
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 730, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 736, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 735, h=0.000000, alpha=2
# ➡️ Leaf indices count: 36
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 733, h=0.000000, alpha=2
# ➡️ Leaf indices count: 46
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 729, h=0.000000, alpha=2
# ➡️ Leaf indices count: 69
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 727, h=0.000000, alpha=2
# ➡️ Leaf indices count: 83
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 715, h=0.000000, alpha=2
# ➡️ Leaf indices count: 166
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 709, h=0.000000, alpha=2
# ➡️ Leaf indices count: 203
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 742, h=0.000000, alpha=2
# ➡️ Leaf indices count: 26
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 740, h=0.000000, alpha=2
# ➡️ Leaf indices count: 37
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 708, h=0.000000, alpha=2
# ➡️ Leaf indices count: 240
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 746, h=0.000000, alpha=2
# ➡️ Leaf indices count: 20
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 760, h=0.000000, alpha=2
# ➡️ Leaf indices count: 31
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 758, h=0.000000, alpha=2
# ➡️ Leaf indices count: 42
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 757, h=0.000000, alpha=2
# ➡️ Leaf indices count: 54
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 768, h=0.000000, alpha=2
# ➡️ Leaf indices count: 24
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 766, h=0.000000, alpha=2
# ➡️ Leaf indices count: 38
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 764, h=0.000000, alpha=2
# ➡️ Leaf indices count: 55
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 756, h=0.000000, alpha=2
# ➡️ Leaf indices count: 109
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 773, h=0.000000, alpha=2
# ➡️ Leaf indices count: 32
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 772, h=0.000000, alpha=2
# ➡️ Leaf indices count: 45
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 779, h=0.000000, alpha=2
# ➡️ Leaf indices count: 36
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 778, h=0.000000, alpha=2
# ➡️ Leaf indices count: 52
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 777, h=0.000000, alpha=2
# ➡️ Leaf indices count: 71
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 771, h=0.000000, alpha=2
# ➡️ Leaf indices count: 116
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 755, h=0.000000, alpha=2
# ➡️ Leaf indices count: 225
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 754, h=0.000000, alpha=2
# ➡️ Leaf indices count: 236
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 785, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 753, h=0.000000, alpha=2
# ...
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22791, h=0.000000, alpha=2
# ➡️ Leaf indices count: 33
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22787, h=0.000000, alpha=2
# ➡️ Leaf indices count: 56
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22786, h=0.000000, alpha=2
# ➡️ Leaf indices count: 70
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22785, h=0.000000, alpha=2
# ➡️ Leaf indices count: 88
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22808, h=0.000000, alpha=2
# ➡️ Leaf indices count: 27
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22806, h=0.000000, alpha=2
# ➡️ Leaf indices count: 37
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22804, h=0.000000, alpha=2
# ➡️ Leaf indices count: 47
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22803, h=0.000000, alpha=2
# ➡️ Leaf indices count: 62
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22802, h=0.000000, alpha=2
# ➡️ Leaf indices count: 76
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22816, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22815, h=0.000000, alpha=2
# ➡️ Leaf indices count: 35
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22813, h=0.000000, alpha=2
# ➡️ Leaf indices count: 45
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22801, h=0.000000, alpha=2
# ➡️ Leaf indices count: 121
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22823, h=0.000000, alpha=2
# ➡️ Leaf indices count: 28
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22828, h=0.000000, alpha=2
# ➡️ Leaf indices count: 21
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22826, h=0.000000, alpha=2
# ➡️ Leaf indices count: 36
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22822, h=0.000000, alpha=2
# ➡️ Leaf indices count: 64
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22820, h=0.000000, alpha=2
# ➡️ Leaf indices count: 82
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22800, h=0.000000, alpha=2
# ➡️ Leaf indices count: 203
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22798, h=0.000000, alpha=2
# ➡️ Leaf indices count: 213
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22784, h=0.000000, alpha=2
# ➡️ Leaf indices count: 301
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22766, h=0.000000, alpha=2
# ➡️ Leaf indices count: 418
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22764, h=0.000000, alpha=2
# ➡️ Leaf indices count: 429
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22833, h=0.000000, alpha=2
# ➡️ Leaf indices count: 29
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22832, h=0.000000, alpha=2
# ➡️ Leaf indices count: 42
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22837, h=0.000000, alpha=2
# ➡️ Leaf indices count: 26
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22831, h=0.000000, alpha=2
# ➡️ Leaf indices count: 68
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22763, h=0.000000, alpha=2
# ➡️ Leaf indices count: 497
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22762, h=0.000000, alpha=2
# ➡️ Leaf indices count: 508
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22758, h=0.000000, alpha=2
# ➡️ Leaf indices count: 540
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22754, h=0.000000, alpha=2
# ➡️ Leaf indices count: 561
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22742, h=0.000000, alpha=2
# ➡️ Leaf indices count: 627
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22741, h=0.000000, alpha=2
# ➡️ Leaf indices count: 642
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22842, h=0.000000, alpha=2
# ➡️ Leaf indices count: 21
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22740, h=0.000000, alpha=2
# ➡️ Leaf indices count: 663
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22728, h=0.000000, alpha=2
# ➡️ Leaf indices count: 741
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22724, h=0.000000, alpha=2
# ➡️ Leaf indices count: 762
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22845, h=0.000000, alpha=2
# ➡️ Leaf indices count: 20
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22723, h=0.000000, alpha=2
# ➡️ Leaf indices count: 782
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22853, h=0.000000, alpha=2
# ➡️ Leaf indices count: 21
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22856, h=0.000000, alpha=2
# ➡️ Leaf indices count: 21
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22852, h=0.000000, alpha=2
# ➡️ Leaf indices count: 42
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22850, h=0.000000, alpha=2
# ➡️ Leaf indices count: 55
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22848, h=0.000000, alpha=2
# ➡️ Leaf indices count: 65
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22722, h=0.000000, alpha=2
# ➡️ Leaf indices count: 847
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22866, h=0.000000, alpha=2
# ➡️ Leaf indices count: 35
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22864, h=0.000000, alpha=2
# ➡️ Leaf indices count: 49
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22862, h=0.000000, alpha=2
# ➡️ Leaf indices count: 64
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22861, h=0.000000, alpha=2
# ➡️ Leaf indices count: 75
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22859, h=0.000000, alpha=2
# ➡️ Leaf indices count: 89
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22721, h=0.000000, alpha=2
# ➡️ Leaf indices count: 936
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22873, h=0.000000, alpha=2
# ➡️ Leaf indices count: 30
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22872, h=0.000000, alpha=2
# ➡️ Leaf indices count: 46
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22870, h=0.000000, alpha=2
# ➡️ Leaf indices count: 58
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22720, h=0.000000, alpha=2
# ➡️ Leaf indices count: 994
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22650, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1452
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22614, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1694
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22878, h=0.000000, alpha=2
# ➡️ Leaf indices count: 20
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22877, h=0.000000, alpha=2
# ➡️ Leaf indices count: 30
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22613, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1724
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22581, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1923
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22882, h=0.000000, alpha=2
# ➡️ Leaf indices count: 31
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22580, h=0.000000, alpha=2
# ➡️ Leaf indices count: 1954
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22886, h=0.000000, alpha=2
# ➡️ Leaf indices count: 33
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22899, h=0.000000, alpha=2
# ➡️ Leaf indices count: 30
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22897, h=0.000000, alpha=2
# ➡️ Leaf indices count: 40
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22895, h=0.000000, alpha=2
# ➡️ Leaf indices count: 52
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22906, h=0.000000, alpha=2
# ➡️ Leaf indices count: 36
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22904, h=0.000000, alpha=2
# ➡️ Leaf indices count: 49
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22902, h=0.000000, alpha=2
# ➡️ Leaf indices count: 60
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22894, h=0.000000, alpha=2
# ➡️ Leaf indices count: 112
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22893, h=0.000000, alpha=2
# ➡️ Leaf indices count: 124
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22911, h=0.000000, alpha=2
# ➡️ Leaf indices count: 26
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22910, h=0.000000, alpha=2
# ➡️ Leaf indices count: 37
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22892, h=0.000000, alpha=2
# ➡️ Leaf indices count: 161
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22891, h=0.000000, alpha=2
# ➡️ Leaf indices count: 172
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22916, h=0.000000, alpha=2
# ➡️ Leaf indices count: 33
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22890, h=0.000000, alpha=2
# ➡️ Leaf indices count: 205
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22920, h=0.000000, alpha=2
# ➡️ Leaf indices count: 27
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22926, h=0.000000, alpha=2
# ➡️ Leaf indices count: 21
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22929, h=0.000000, alpha=2
# ➡️ Leaf indices count: 34
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22925, h=0.000000, alpha=2
# ➡️ Leaf indices count: 55
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22923, h=0.000000, alpha=2
# ➡️ Leaf indices count: 69
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22919, h=0.000000, alpha=2
# ➡️ Leaf indices count: 96
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22889, h=0.000000, alpha=2
# ➡️ Leaf indices count: 301
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22885, h=0.000000, alpha=2
# ➡️ Leaf indices count: 334
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22579, h=0.000000, alpha=2
# ➡️ Leaf indices count: 2288
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22577, h=0.000000, alpha=2
# ➡️ Leaf indices count: 2305
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22932, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22576, h=0.000000, alpha=2
# ➡️ Leaf indices count: 2330
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 19104, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25165
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22936, h=0.000000, alpha=2
# ➡️ Leaf indices count: 35
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22946, h=0.000000, alpha=2
# ➡️ Leaf indices count: 20
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22944, h=0.000000, alpha=2
# ➡️ Leaf indices count: 38
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22943, h=0.000000, alpha=2
# ➡️ Leaf indices count: 49
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22941, h=0.000000, alpha=2
# ➡️ Leaf indices count: 61
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22950, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22940, h=0.000000, alpha=2
# ➡️ Leaf indices count: 86
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22957, h=0.000000, alpha=2
# ➡️ Leaf indices count: 29
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22955, h=0.000000, alpha=2
# ➡️ Leaf indices count: 45
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22953, h=0.000000, alpha=2
# ➡️ Leaf indices count: 62
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22939, h=0.000000, alpha=2
# ➡️ Leaf indices count: 148
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22935, h=0.000000, alpha=2
# ➡️ Leaf indices count: 183
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 19103, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25348
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22964, h=0.000000, alpha=2
# ➡️ Leaf indices count: 26
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22963, h=0.000000, alpha=2
# ➡️ Leaf indices count: 38
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22961, h=0.000000, alpha=2
# ➡️ Leaf indices count: 48
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22971, h=0.000000, alpha=2
# ➡️ Leaf indices count: 20
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22977, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22980, h=0.000000, alpha=2
# ➡️ Leaf indices count: 28
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22976, h=0.000000, alpha=2
# ➡️ Leaf indices count: 53
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22974, h=0.000000, alpha=2
# ➡️ Leaf indices count: 72
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22970, h=0.000000, alpha=2
# ➡️ Leaf indices count: 92
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22968, h=0.000000, alpha=2
# ➡️ Leaf indices count: 107
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22960, h=0.000000, alpha=2
# ➡️ Leaf indices count: 155
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 19102, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25503
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22985, h=0.000000, alpha=2
# ➡️ Leaf indices count: 23
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22984, h=0.000000, alpha=2
# ➡️ Leaf indices count: 33
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22989, h=0.000000, alpha=2
# ➡️ Leaf indices count: 34
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22983, h=0.000000, alpha=2
# ➡️ Leaf indices count: 67
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 19101, h=0.000000, alpha=2
# ➡️ Leaf indices count: 25570
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22995, h=0.000000, alpha=2
# ➡️ Leaf indices count: 28
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22994, h=0.000000, alpha=2
# ➡️ Leaf indices count: 47
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 23006, h=0.000000, alpha=2
# ➡️ Leaf indices count: 32
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 23004, h=0.000000, alpha=2
# ➡️ Leaf indices count: 51
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 23003, h=0.000000, alpha=2
# ➡️ Leaf indices count: 62
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 23002, h=0.000000, alpha=2
# ➡️ Leaf indices count: 72
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 23001, h=0.000000, alpha=2
# ➡️ Leaf indices count: 84
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 23012, h=0.000000, alpha=2
# ➡️ Leaf indices count: 22
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 23000, h=0.000000, alpha=2
# ➡️ Leaf indices count: 106
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 23015, h=0.000000, alpha=2
# ➡️ Leaf indices count: 31
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22999, h=0.000000, alpha=2
# ➡️ Leaf indices count: 137
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22993, h=0.000000, alpha=2
# ➡️ Leaf indices count: 184
# ➡️ M shape: (1, 2), m0 shape: (1,)
# 🌳 Pruning triggered at node 22992, h=0.000000, alpha=2
# ➡️ Leaf indices count: 194
# ➡️ M shape: (1, 2), m0 shape: (1,)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
COF_model
# Out:
# [{'leaf_id': np.int64(119),
#   'CO_Model': {'M': array([[-1.23378826e-02,  2.06652489e+00],
#           [-1.00000460e+00, -3.03843062e-07]]),
#    'm0': array([1.18663109e-01, 6.81040748e-07]),
#    'h': 0.006782454659385989},
#   'no_samples': 125,
#   'indices': [0,
#    49,
#    78,
#    192,
#    285,
#    456,
#    473,
#    545,
#    558,
#    577,
#    620,
#    668,
#    677,
#    707,
#    815,
#    967,
#    989,
#    1123,
#    1174,
#    1339,
#    1382,
#    1436,
#    1519,
#    1522,
#    1558,
#    1608,
#    1649,
#    1681,
#    1772,
#    1780,
#    1836,
#    1908,
#    1965,
#    2061,
#    2203,
#    2358,
#    2405,
#    2426,
#    2486,
#    2498,
#    2535,
#    2566,
#    2661,
#    2786,
#    2869,
#    3114,
#    3328,
#    8331,
#    8371,
#    8384,
#    8389,
#    8521,
#    8564,
#    8579,
#    8651,
#    8671,
#    8849,
#    8890,
#    8938,
#    8977,
#    8980,
#    8986],
#   'bounds': {'feature_0': (np.float64(0.5618324279785156),
#     np.float64(0.8291740417480469)),
#    'feature_1': (np.float64(-1.0985199213027954),
#     np.float64(-0.7470105886459351))}},
#  {'leaf_id': np.int64(40),
#   'CO_Model': {'M': array([[-1.03604339e-01,  1.61928692e-01],
#           [-1.00000258e+00, -4.74965320e-08]]),
#    'm0': array([-5.07798329e-01, -3.51565644e-07]),
#    'h': 0.1487019958461119},
#   'no_samples': 124,
#   'indices': [3,
#    8,
#    42,
#    196,
#    212,
#    302,
#    344,
#    383,
#    459,
#    499,
#    573,
#    575,
#    686,
#    696,
#    736,
#    808,
#    829,
#    896,
#    942,
#    1005,
#    1116,
#    1210,
#    1353,
#    1525,
#    1537,
#    1548,
#    1844,
#    1878,
#    1919,
#    2069,
#    2150,
#    2211,
#    2335,
#    2357,
#    2359,
#    2574,
#    2634,
#    2700,
#    2714,
#    2965,
#    2988,
#    2998,
#    3055,
#    3129,
#    3242,
#    3266,
#    3289,
#    3349,
#    3424,
#    3452,
#    3492,
#    3655,
#    3700,
#    3838,
#    3906,
#    3926,
#    3937,
#    4017,
#    4168,
#    4210,
#    4382,
#    4659,
#    4706,
#    4728,
#    4756,
#    4777,
#    4799,
#    4803,
#    4857,
#    4972,
#    5045,
#    5143,
#    5202,
#    5243,
#    5268,
#    5400,
#    5514,
#    5529,
#    5534,
#    5543,
#    5573,
#    5591,
#    5824,
#    5855,
#    5941,
#    6145,
#    6219,
#    6493,
#    6534,
#    6627,
#    6767,
#    6785,
#    6792,
#    6902,
#    6912,
#    6975,
#    7047,
#    7079,
#    7129,
#    7162,
#    7238,
#    7366,
#    7492,
#    7533,
#    7566,
#    7570,
#    7681,
#    7703,
#    7922,
#    7929,
#    8205,
#    8206,
#    8290,
#    8455,
#    8565,
#    8610,
#    8634,
#    8637,
#    8744,
#    8745,
#    8795,
#    8837,
#    8887,
#    8902],
#   'bounds': {'feature_0': (np.float64(-0.6087572574615479),
#     np.float64(-0.5397219657897949)),
#    'feature_1': (np.float64(-0.3119409084320068),
#     np.float64(0.5378303527832031))}},
#  {'leaf_id': np.int64(111),
#   'CO_Model': {'M': array([[ 2.93425523e-01,  4.20000735e-01],
#           [-1.00015510e+00, -6.75700762e-06]]),
#    'm0': array([-2.95410296e-01, -9.06893167e-06]),
#    'h': 5.839750528738648},
#   'no_samples': 106,
#   'indices': [4,
#    173,
#    201,
#    348,
#    464,
#    540,
#    543,
#    565,
#    646,
#    816,
#    901,
#    929,
#    972,
#    994,
#    1016,
#    1184,
#    1256,
#    1259,
#    1314,
#    1361,
#    1380,
#    1459,
#    1988,
#    1999,
#    2013,
#    2193,
#    2284,
#    2380,
#    2420,
#    2478,
#    2480,
#    2602,
#    2748,
#    2892,
#    3013,
#    3118,
#    3126,
#    3130,
#    3358,
#    3417,
#    3502,
#    3540,
#    3621,
#    3658,
#    3764,
#    4048,
#   'bounds': {'feature_0': (np.float64(-0.2671819925308227),
#     np.float64(-0.0006296634674072)),
#    'feature_1': (np.float64(-1.0990411043167114),
#     np.float64(-0.7473582029342651))}},
#  {'leaf_id': np.int64(8),
#   'CO_Model': {'M': array([[ 1.99310745e-02,  1.57886208e+00],
#           [-9.99997240e-01, -3.08724520e-08]]),
#    'm0': array([-3.53292232e-01,  3.75886257e-08]),
#    'h': 0.008561329374046437},
#   'no_samples': 100,
#   'indices': [11,
#    63,
#    232,
#    235,
#    247,
#    533,
#    613,
#    712,
#    770,
#    892,
#    894,
#    1001,
#    1059,
#    1096,
#    1122,
#    1154,
#    1207,
#    1225,
#    1255,
#    1285,
#    1576,
#    1700,
#    1991,
#    2052,
#    2054,
#    2109,
#    2124,
#    2196,
#    2232,
#    2677,
#    2758,
#    2836,
#    2870,
#    3077,
#    3093,
#    3183,
#    3258,
#    3315,
#    3416,
#    3525,
#    3541,
#    3649,
#    3656,
#    3657,
#    3860,
#    3919,
#    4268,
#    4457,
#    4566,
#    4568,
#    4787,
#    4850,
#    4870,
#    4887,
#    4948,
#    4958,
#    4977,
#    4990,
#    5006,
#    5032,
#    5047,
#    5056,
#    5119,
#    5451,
#    5530,
#    5547,
#    5597,
#    5625,
#    5628,
#    5838,
#    5873,
#    5933,
#    6032,
#    6046,
#    6274,
#    6488,
#    6513,
#    6551,
#    6643,
#    6677,
#    6905,
#    7058,
#    7086,
#    7204,
#    7324,
#    7509,
#    7671,
#    7722,
#    7745,
#    7783,
#    7971,
#    8209,
#    8292,
#    8307,
#    8407,
#    8494,
#    8701,
#    8710,
#    8822,
#    8880],
#   'bounds': {'feature_0': (np.float64(-0.8346962928771973),
#     np.float64(-0.5487539768218994)),
#    'feature_1': (np.float64(-0.9168933629989624),
#     np.float64(-0.7390291690826416))}},
#  {'leaf_id': np.int64(39),
#   'CO_Model': {'M': array([[ 1.49242188e-01,  1.83739318e-01],
#           [-9.99999093e-01,  1.56224281e-08]]),
#    'm0': array([-3.50931723e-01,  1.29127316e-07]),
#    'h': 0.14037675604933297},
#   'no_samples': 106,
#   'indices': [12,
#    124,
#    469,
#    697,
#    701,
#    794,
#    905,
#    1266,
#    1280,
#    1298,
#    1447,
#    1655,
#    1835,
#    1861,
#    1987,
#    2012,
#    2041,
#    2167,
#    2305,
#    2317,
#    2344,
#    2424,
#    2431,
#    2510,
#    2533,
#    2614,
#    2704,
#    2776,
#    2779,
#    2801,
#    2884,
#    2947,
#    3027,
#    3212,
#    3360,
#    3393,
#    3414,
#    3483,
#    3487,
#    3730,
#    3752,
#    3869,
#    3967,
#    4029,
#    4078,
#    4098,
#    4199,
#    4257,
#    4302,
#    4482,
#    4533,
#    4558,
#    4619,
#    4634,
#    4734,
#    4840,
#    4877,
#    4912,
#    5050,
#    5147,
#    5212,
#    5280,
#    5304,
#    5358,
#    5419,
#    5725,
#    6030,
#    6056,
#    6158,
#    6171,
#    6187,
#    6285,
#    6312,
#    6395,
#    6461,
#    6514,
#    6583,
#    6665,
#    6666,
#    6694,
#    6827,
#    6914,
#    6962,
#    7056,
#    7093,
#    7102,
#    7105,
#    7198,
#    7229,
#    7532,
#    7550,
#    7585,
#    7616,
#    7795,
#    7831,
#    7898,
#    8092,
#    8157,
#    8183,
#    8357,
#    8419,
#    8529,
#    8614,
#    8747,
#    8809,
#    8843],
#   'bounds': {'feature_0': (np.float64(-0.6739517450332642),
#     np.float64(-0.6104140281677246)),
#    'feature_1': (np.float64(-0.3317122459411621),
#     np.float64(0.542805552482605))}},
#  {'leaf_id': np.int64(62),
#   'CO_Model': {'M': array([[-4.86770523e-02,  1.83376146e-01],
#           [-9.99976643e-01,  3.46368857e-07]]),
#    'm0': array([-4.54513505e-01,  3.79212920e-06]),
#    'h': 0.16563697947780592},
#   'no_samples': 131,
#   'indices': [13,
#    269,
#    450,
#    497,
#    510,
#    528,
#    672,
#    868,
#    926,
#    1012,
#    1070,
#    1113,
#    1146,
#    1269,
#    1326,
#    1432,
#    1453,
#    1462,
#    1559,
#    1631,
#    1658,
#    1820,
#    2001,
#    2008,
#    2104,
#    2105,
#    2386,
#    2389,
#    2515,
#    2580,
#    2596,
#    2597,
#    2600,
#    2611,
#    2649,
#    2690,
#    2792,
#    2809,
#    2864,
#    2866,
#    2948,
#    3039,
#    3172,
#    3173,
#    3294,
#    3313,
#    3402,
#    3405,
#    3490,
#    3645,
#    3798,
#    3823,
#    3904,
#    3942,
#    3968,
#    4011,
#    4100,
#    4112,
#    4171,
#    4278,
#    4281,
#    4296,
#    4303,
#    4316,
#    4461,
#    4507,
#    4520,
#    4625,
#    4727,
#    4729,
#    4747,
#    4760,
#    4789,
#    4928,
#    5074,
#    5087,
#    5115,
#    5122,
#    5155,
#    5195,
#    5252,
#    5375,
#    5423,
#    5484,
#    5528,
#    5545,
#    5635,
#    5722,
#    6029,
#    6085,
#    6166,
#    6239,
#    6278,
#    6313,
#    6413,
#    6431,
#    6459,
#    6485,
#    6697,
#    6730,
#    6862,
#    6876,
#    6897,
#    6939,
#    6967,
#    6998,
#    7064,
#    7117,
#    7152,
#    7158,
#    7429,
#    7439,
#    7519,
#    7598,
#    7756,
#    7763,
#    7767,
#    7943,
#    8079,
#    8087,
#    8124,
#    8336,
#    8438,
#    8526,
#    8602,
#    8616,
#    8635,
#    8804,
#    8850,
#    8935,
#    8963],
#   'bounds': {'feature_0': (np.float64(-0.137876272201538),
#     np.float64(-0.0698237419128418)),
#    'feature_1': (np.float64(-0.329369306564331),
#     np.float64(0.5237007737159729))}},
#  {'leaf_id': np.int64(18),
#   'CO_Model': {'M': array([[-3.68623359e-03,  2.51017525e+00],
#           [-9.99998749e-01, -3.16402783e-09]]),
#    'm0': array([3.30876294e-01, 4.87497603e-09]),
#    'h': 0.0007152517761532273},
#   'no_samples': 118,
#   'indices': [14,
#    152,
#    178,
#    184,
#    194,
#    440,
#    474,
#    482,
#    698,
#    705,
#    752,
#    793,
#    813,
#    823,
#    826,
#    848,
#    900,
#    1220,
#    1272,
#    1276,
#    1294,
#    1315,
#    1513,
#    1531,
#    1533,
#    1623,
#    1628,
#    1902,
#    1966,
#    1975,
#    1984,
#    2086,
#    2135,
#    2191,
#    2230,
#    2244,
#    2265,
#    2287,
#    2322,
#    2369,
#    2393,
#    2428,
#    2553,
#    2626,
#    2681,
#    2728,
#    2926,
#    2967,
#    2968,
#    3029,
#    3189,
#    3325,
#    3412,
#    3556,
#    3716,
#    3902,
#    3988,
#    4134,
#    4139,
#    4273,
#    4415,
#    4514,
#    4686,
#    4831,
#    4838,
#    4871,
#    4875,
#    5017,
#    5239,
#    5554,
#    5575,
#    5576,
#    5735,
#    5888,
#    5923,
#    5992,
#    6117,
#    6162,
#    6198,
#    6233,
#    6355,
#    6409,
#    6427,
#    6467,
#    6483,
#    6508,
#    6606,
#    6824,
#    6841,
#    7005,
#    7012,
#    7037,
#    7038,
#    7068,
#    7185,
#    7191,
#    7199,
#    7338,
#    7360,
#    7384,
#    7543,
#    7573,
#    7618,
#    7623,
#    7645,
#    7659,
#    7706,
#    7776,
#    7817,
#    7974,
#    8032,
#    8096,
#    8221,
#    8250,
#    8380,
#    8489,
#    8707,
#    8997],
#   'bounds': {'feature_0': (np.float64(-0.2700831890106201),
#     np.float64(-0.0022040605545043)),
#    'feature_1': (np.float64(-0.7463324069976807),
#     np.float64(-0.548214316368103))}},
#  {'leaf_id': np.int64(54),
#   'CO_Model': {'M': array([[-4.83824321e-02,  6.40649879e-01],
#           [-1.00001014e+00,  1.85675292e-06]]),
#    'm0': array([-3.84041164e-01, -9.35437981e-06]),
#    'h': 0.03117213957250772},
#   'no_samples': 100,
#   'indices': [15,
#    103,
#    119,
#    200,
#    239,
#    325,
#    338,
#    568,
#    642,
#    673,
#    704,
#    820,
#    982,
#    1002,
#    1025,
#    1048,
#    1054,
#    1073,
#    1153,
#    1274,
#    1383,
#    1418,
#    1458,
#    1461,
#    1500,
#    1575,
#    1632,
#    1653,
#    1696,
#    1754,
#    1833,
#    1936,
#    2051,
#    2055,
#    2111,
#    2123,
#    2154,
#    2280,
#    2309,
#    2392,
#    2545,
#    2568,
#    2718,
#    2730,
#    2861,
#    2883,
#    2949,
#    3079,
#    3105,
#    3108,
#    3112,
#    3314,
#    3345,
#    3736,
#    3862,
#    3891,
#    3934,
#    4181,
#    4405,
#    4491,
#    4827,
#    5009,
#    5305,
#    5354,
#    5413,
#    5456,
#    5604,
#    5800,
#    5931,
#    6028,
#    6217,
#    6328,
#    6333,
#    6371,
#    6463,
#    6468,
#    6915,
#    6972,
#    7133,
#    7227,
#    7354,
#    7387,
#    7538,
#    7579,
#    7620,
#    7705,
#    7741,
#    7813,
#    7854,
#    8088,
#    8137,
#    8246,
#    8255,
#    8382,
#    8390,
#    8460,
#    8574,
#    8586,
#    8888,
#    8889],
#   'bounds': {'feature_0': (np.float64(-0.5367225408554077),
#     np.float64(-0.4053316116333008)),
#    'feature_1': (np.float64(-0.3406044244766235),
#     np.float64(-0.0217316150665283))}},
#  {'leaf_id': np.int64(135),
#   'CO_Model': {'M': array([[-1.97071738e-01, -1.66829889e-01],
#           [-9.99990970e-01, -1.78204481e-07]]),
#    'm0': array([ 3.42056277e-01, -2.39092471e-07]),
#    4779,
#    4858,
#    4897,
#    5096,
#    5159,
#    5193,
#    5362,
#    5415,
#    5471,
#    5513,
#    5564,
#    5711,
#    5782,
#    5797,
#    5875,
#    5917,
#    5919,
#    6023,
#    6197,
#    6207,
#    6610,
#    6663,
#    6753,
#    6986,
#    7003,
#    7170,
#    7318,
#    7392,
#    7432,
#    7469,
#    7762,
#    7788,
#    7789,
#    7874,
#    7947,
#    7982,
#    8060,
#    8346,
#    8348,
#    8451,
#    8453,
#    8621,
#    8790,
#    8892,
#    8964,
#    8992],
#   'bounds': {'feature_0': (np.float64(0.0008682012557983),
#     np.float64(0.1459389925003051)),
#    'feature_1': (np.float64(0.5579262971878052),
#     np.float64(0.939084768295288))}},
#  {'leaf_id': np.int64(124),
#   'CO_Model': {'M': array([[-1.59494634e-02,  1.94537139e-01],
#           [-9.99995381e-01, -9.26718311e-08]]),
#    'm0': array([-4.33975589e-01, -5.69941201e-07]),
#    'h': 0.14331391811430838},
#   'no_samples': 102,
#   'indices': [19,
#    274,
#    317,
#    346,
#    476,
#    486,
#    532,
#    549,
#    766,
#    800,
#    883,
#    910,
#    949,
#    1079,
#    1183,
#    1412,
#    1449,
#    1482,
#    1552,
#    1663,
#    1726,
#    1798,
#    1880,
#    1970,
#    2118,
#    2207,
#    2229,
#    2248,
#    2330,
#    2377,
#    2549,
#    2610,
#    2631,
#    2663,
#    2831,
#    2845,
#    2876,
#    2914,
#    3052,
#    3106,
#    3186,
#    3200,
#    3244,
#    3300,
#    3574,
#    3759,
#    3815,
#    3863,
#    3949,
#    3996,
#    4356,
#    4358,
#    4393,
#    4726,
#    4806,
#    4987,
#    5003,
#    5033,
#    5128,
#    5151,
#    5210,
#    5232,
#    5240,
#    5259,
#    5533,
#    5748,
#    5769,
#    5863,
#    5890,
#    5960,
#    6108,
#    6338,
#    6549,
#    6572,
#    6574,
#    6700,
#    6714,
#    6722,
#    6756,
#    6793,
#    6899,
#    6909,
#    6940,
#    6987,
#    7242,
#    7270,
#    7313,
#    7349,
#    7352,
#    7359,
#    7699,
#    7754,
#    8073,
#    8108,
#    8123,
#    8305,
#    8427,
#    8511,
#    8535,
#    8573,
#    8685,
#    8717],
#   'bounds': {'feature_0': (np.float64(0.6886603832244873),
#     np.float64(0.7483583688735962)),
#    'feature_1': (np.float64(-0.3265317678451538),
#     np.float64(0.5376120209693909))}},
#  {'leaf_id': np.int64(11),
#   'CO_Model': {'M': array([[ 3.89187192e-03,  2.51647162e+00],
#           [-9.99997686e-01, -2.32057052e-08]]),
#    'm0': array([3.38085537e-01, 3.60808442e-08]),
#    'h': 0.00035624929126668514},
#   'no_samples': 101,
#   'indices': [20,
#    114,
#    126,
#    169,
#    214,
#    228,
#    567,
#    804,
#    806,
#    839,
#    898,
#    1119,
#    1197,
#    1561,
#    1589,
#    1599,
#    1734,
#    1875,
#    1934,
#    1995,
#    2044,
#    2046,
#    2233,
#    2286,
#    2383,
#    2507,
#    2587,
#    2751,
#    2910,
#    3045,
#    3061,
#    3081,
#    3185,
#    3222,
#    3461,
#    3501,
#    3626,
#    3804,
#    3952,
#    3961,
#    3995,
#    4079,
#    4089,
#    4128,
#    4175,
#    4218,
#    4304,
#    4394,
#    4406,
#    4443,
#    4452,
#    4598,
#    4611,
#    4713,
#    4752,
#    4929,
#    4943,
#    4966,
#    4989,
#    5290,
#    5406,
#    5411,
#    5559,
#    5657,
#    5718,
#    5749,
#    5898,
#    5955,
#    6098,
#    6102,
#    6160,
#    6176,
#    6210,
#    6216,
#    6322,
#    6436,
#    6489,
#    6537,
#    6777,
#    6782,
#    6872,
#    7259,
#    7327,
#    7398,
#    7413,
#    7414,
#    7454,
#    7560,
#    7719,
#    7790,
#    7822,
#    7945,
#    8055,
#    8080,
#    8251,
#    8318,
#    8550,
#    8706,
#    8819,
#    8944,
#    8946],
#   'bounds': {'feature_0': (np.float64(-0.8171982765197754),
#     np.float64(-0.5544073581695557)),
#    'feature_1': (np.float64(-0.737180233001709),
#     np.float64(-0.548094630241394))}},
#  {'leaf_id': np.int64(30),
#   'CO_Model': {'M': array([[ 4.08625312e-02,  1.99507787e-01],
#           [-1.00001773e+00, -8.16826523e-07]]),
#    'm0': array([-4.10419754e-01, -6.13644079e-06]),
#    'h': 0.14038585327251762},
#   'no_samples': 102,
#   'indices': [21,
#    105,
#    139,
#    180,
#    400,
#    506,
#    682,
#    687,
#    954,
#    1120,
#    1155,
#    1303,
#    1305,
#    1332,
#    1351,
#    1381,
#    1408,
#    1516,
#    1530,
#    1652,
#    1723,
#    1747,
#    1911,
#    2088,
#    2089,
#    2212,
#    2310,
#    2479,
#    2531,
#    2589,
#    2622,
#    2653,
#    2671,
#    2738,
#    2766,
#    2784,
#    3054,
#    3174,
#    3264,
#    3283,
#    3343,
#    3497,
#    3549,
#    3859,
#    3982,
#    4010,
#    4126,
#    4144,
#    4447,
#    4448,
#    4492,
#    4498,
#    4585,
#    4594,
#    4624,
#    4663,
#    4678,
#    4701,
#    4749,
#    4823,
#    4941,
#    5089,
#    5517,
#    5783,
#    5843,
#    5866,
#    5878,
#    6049,
#    6074,
#    6111,
#    6353,
#    6359,
#    6457,
#    6458,
#    6469,
#    6599,
#    6608,
#    6687,
#    6771,
#    6900,
#    6907,
#    6978,
#    7009,
#    7099,
#    7277,
#    7290,
#    7433,
#    7487,
#    7721,
#    7960,
#    8093,
#    8162,
#    8275,
#    8372,
#    8726,
#    8793,
#    8839,
#    8872,
#    8882,
#    8920,
#    8957,
#    8968],
#   'bounds': {'feature_0': (np.float64(-1.0239096879959106),
#     np.float64(-0.9532779455184937)),
#    'feature_1': (np.float64(-0.3235042095184326),
#     np.float64(0.5450132489204407))}},
#  {'leaf_id': np.int64(74),
#   'CO_Model': {'M': array([[-4.69285940e-03,  9.00394256e-01],
#           [-9.99988755e-01,  1.32316575e-09]]),
#    'm0': array([-9.30167345e-01, -1.42719723e-09]),
#    'h': 0.19000368001333945},
#   'no_samples': 194,
#   'indices': [22,
#    68,
#    116,
#    225,
#    361,
#    427,
#    429,
#    455,
#    523,
#    585,
#    597,
#    761,
#    809,
#    838,
#    842,
#    884,
#    916,
#    3844,
#    3864,
#    3911,
#    3938,
#    4051,
#    4106,
#    4160,
#    4597,
#    4814,
#    4908,
#    4970,
#    5230,
#    5231,
#    5279,
#    5295,
#    5384,
#    5568,
#    5586,
#    5596,
#    5675,
#    5719,
#    5733,
#    5770,
#    6031,
#    6135,
#    6553,
#    6595,
#    6616,
#    6683,
#    6745,
#    6804,
#    6991,
#    7000,
#    7051,
#    7098,
#    7120,
#    7146,
#    7221,
#    7380,
#    7401,
#    7711,
#    7798,
#    7889,
#    7908,
#    7941,
#    8159,
#    8338,
#    8490,
#    8510,
#    8533,
#    8609,
#    8694,
#    8716,
#    8797,
#    8875,
#    8901],
#   'bounds': {'feature_0': (np.float64(0.2746480703353882),
#     np.float64(0.4123653173446655)),
#    'feature_1': (np.float64(-0.3319319486618042),
#     np.float64(-0.01063072681427))}},
#  {'leaf_id': np.int64(114),
#   'CO_Model': {'M': array([[ 2.74446615e-01, -3.65823007e-01],
#           [-9.99927463e-01, -3.49772529e-05]]),
#    'm0': array([ 1.14711602e-01, -4.63642348e-05]),
#    'h': 8.195279064158742},
#   'no_samples': 100,
#   'indices': [30,
#    46,
#    223,
#    243,
#    286,
#    347,
#    360,
#    525,
#    526,
#    544,
#    596,
#    650,
#    726,
#    877,
#    913,
#    1111,
#    1152,
#    1452,
#    1456,
#    1484,
#    1489,
#    1504,
#    1643,
#    1867,
#    2005,
#    2072,
#    2163,
#    2454,
#    2679,
#    2693,
#    2814,
#    2918,
#    3062,
#    3226,
#    3246,
#    3270,
#    3356,
#    3652,
#    3745,
#    3825,
#    3842,
#    4040,
#    4449,
#    4487,
#    4656,
#    4707,
#    4851,
#    4880,
#    4910,
#    5165,
#    5188,
#    5246,
#    5262,
#    5320,
#    5421,
#    5522,
#    5561,
#    5613,
#    5619,
#    5636,
#    5665,
#    5915,
#    5926,
#    6001,
#    6004,
#    6020,
#    6222,
#    6256,
#    6262,
#    6283,
#    6295,
#    6498,
#    6509,
#    6525,
#    6536,
#    6560,
#    6657,
#    6671,
#    6842,
#    7190,
#    7202,
#    7210,
#    7350,
#    7420,
#    7646,
#    7843,
#    7853,
#    7871,
#    8063,
#    8241,
#    8353,
#    8385,
#    8395,
#    8498,
#    8516,
#    8660,
#    8721,
#    8731,
#    8841,
#    8985],
#   'bounds': {'feature_0': (np.float64(0.4248884320259094),
#     np.float64(0.5539065003395081)),
#    'feature_1': (np.float64(0.553784966468811),
#     np.float64(0.9451193809509276))}},
#  {'leaf_id': np.int64(44),
#   'CO_Model': {'M': array([[-2.28076437e-02,  1.00968675e+00],
#           [-9.99994185e-01,  1.14603750e-07]]),
#    'm0': array([-5.32641773e-01,  1.49549602e-07]),
#    'h': 0.43566346357885105},
#   'no_samples': 180,
#   'indices': [31,
#    195,
#    207,
#    253,
#    371,
#    375,
#    379,
#    387,
#    403,
#    418,
#    483,
#    566,
#    580,
#    637,
#    674,
#    764,
#    778,
#    801,
#    837,
#    860,
#    865,
#    867,
#    881,
#    917,
#    988,
#    1008,
#    1011,
#    1017,
#    1078,
#    1163,
#    1330,
#    5160,
#    5180,
#    5253,
#    5257,
#    5355,
#    5431,
#    5646,
#    5672,
#    5686,
#    5918,
#    5937,
#    6172,
#    6209,
#    6220,
#    6290,
#    6379,
#    6462,
#    6487,
#    6506,
#    6562,
#    6740,
#    6846,
#    6964,
#    7116,
#    7137,
#    7223,
#    7263,
#    7300,
#    7315,
#    7426,
#    7527,
#    7541,
#    7657,
#    7715,
#    7870,
#    7873,
#    8019,
#    8150,
#    8486,
#    8518,
#    8654,
#    8785,
#    8820,
#    8848,
#    8862,
#    8907,
#    8936,
#    8959],
#   'bounds': {'feature_0': (np.float64(-0.8785693645477295),
#     np.float64(-0.8143395185470581)),
#    'feature_1': (np.float64(-0.3170781135559082),
#     np.float64(0.5443792343139648))}},
#  {'leaf_id': np.int64(79),
#   'CO_Model': {'M': array([[-5.71183632e-03,  2.51253383e+00],
#           [-9.99998987e-01,  2.57174449e-09]]),
#    'm0': array([ 3.33807876e-01, -4.02680377e-09]),
#    'h': 0.0005086131382803398},
#   'no_samples': 109,
#   'indices': [34,
#    62,
#    71,
#    277,
#    501,
#    537,
#    611,
#    688,
#    708,
#    779,
#    791,
#    832,
#    932,
#    981,
#    1040,
#    1149,
#    1235,
#    1237,
#    1321,
#    1611,
#    1625,
#    1738,
#    2133,
#    2316,
#    2356,
#    2423,
#    2606,
#    2659,
#    2676,
#    2688,
#    2757,
#    2815,
#    2868,
#    3017,
#    3237,
#    3443,
#    3526,
#    3557,
#    3583,
#    3619,
#    3958,
#    4083,
#    4188,
#    4190,
#    4502,
#    4523,
#    4689,
#    4792,
#    4981,
#    5035,
#    5064,
#    5086,
#    5101,
#    5148,
#    5181,
#    5218,
#    5357,
#    5408,
#    5503,
#    5504,
#    5668,
#    5830,
#    5882,
#    5896,
#    6000,
#    6146,
#    6248,
#    6257,
#    6321,
#    6404,
#    6405,
#    6441,
#    6453,
#    6546,
#    6593,
#    6603,
#    6680,
#    6935,
#    6950,
#    6974,
#    7015,
#    7115,
#    7119,
#    7280,
#    7575,
#    7589,
#    7605,
#    7672,
#    7742,
#    7771,
#    7829,
#    7830,
#    7985,
#    8066,
#    8163,
#    8179,
#    8282,
#    8423,
#    8424,
#    8468,
#    8534,
#    8559,
#    8771,
#    8808,
#    8823,
#    8943,
#    8973,
#    8995,
#    8998],
#   'bounds': {'feature_0': (np.float64(0.0042369365692138),
#     np.float64(0.2582714557647705)),
#    'feature_1': (np.float64(-0.7365891933441162),
#     np.float64(-0.5492566823959351))}},
#  {'leaf_id': np.int64(68),
#   'CO_Model': {'M': array([[ 7.22067648e-02,  3.65356654e+00],
#           [-9.99987246e-01,  2.48674257e-07]]),
#    'm0': array([-5.15548273e+00,  2.42595009e-07]),
#    'h': 27.72140228268444},
#   'no_samples': 163,
#   'indices': [35,
#    145,
#    216,
#    303,
#    343,
#    576,
#    616,
#    641,
#    657,
#    678,
#    727,
#    760,
#    775,
#    818,
#    889,
#    897,
#    914,
#    986,
#    1007,
#    1013,
#    1069,
#    1095,
#    1117,
#    1127,
#    1209,
#    1309,
#    1328,
#    1402,
#    8958,
#    8965],
#   'bounds': {'feature_0': (np.float64(-0.2654969692230224),
#     np.float64(-0.000341773033142)),
#    'feature_1': (np.float64(0.5449270009994507),
#     np.float64(0.9436417818069458))}},
#  {'leaf_id': np.int64(17),
#   'CO_Model': {'M': array([[-3.34312345e-03,  2.49838619e+00],
#           [-9.99998831e-01, -1.15563252e-08]]),
#    'm0': array([3.22764725e-01, 1.78650966e-08]),
#    'h': 0.0007685711530636685},
#   'no_samples': 113,
#   'indices': [41,
#    43,
#    79,
#    221,
#    287,
#    503,
#    617,
#    639,
#    745,
#    777,
#    858,
#    1038,
#    1047,
#    1105,
#    1134,
#    1158,
#    1162,
#    1204,
#    1229,
#    1300,
#    1347,
#    1439,
#    1473,
#    1509,
#    1676,
#    1923,
#    1976,
#    1982,
#    2158,
#    2197,
#    2218,
#    2318,
#    2408,
#    2586,
#    2731,
#    2732,
#    2746,
#    2855,
#    2916,
#    2986,
#    3033,
#    3071,
#    3082,
#    3133,
#    3279,
#    3326,
#    3392,
#    3594,
#    3614,
#    3639,
#    3761,
#    3883,
#    3907,
#    3959,
#    4378,
#    4539,
#    4542,
#    4600,
#    4601,
#    4605,
#    4667,
#    4708,
#    4724,
#    4766,
#    4895,
#    5068,
#    5191,
#    5209,
#    5249,
#    5250,
#    5372,
#    5616,
#    5849,
#    6151,
#    6194,
#    6204,
#    6245,
#    6251,
#    6265,
#    6298,
#    6326,
#    6446,
#    6447,
#    6600,
#    6620,
#    6757,
#    6834,
#    6835,
#    6977,
#    6981,
#    7026,
#    7087,
#    7096,
#    7218,
#    7336,
#    7345,
#    7373,
#    7382,
#    7576,
#    7578,
#    7673,
#    7717,
#    7808,
#    8007,
#    8052,
#    8071,
#    8142,
#    8178,
#    8377,
#    8409,
#    8648,
#    8910,
#    8976],
#   'bounds': {'feature_0': (np.float64(-0.5479073524475098),
#     np.float64(-0.2744696140289306)),
#    'feature_1': (np.float64(-0.7428463697433472),
#     np.float64(-0.5450552701950073))}},
#  {'leaf_id': np.int64(134),
#   'CO_Model': {'M': array([[ 6.40489699e-02, -1.15330389e-01],
#           [-9.99955987e-01, -8.15025045e-07]]),
#    'm0': array([ 6.64426677e-02, -1.11724082e-06]),
#    'h': 14.342485475486235},
#   'no_samples': 195,
#   'indices': [44,
#    58,
#    75,
#    101,
#    167,
#    209,
#    227,
#    313,
#    435,
#    437,
#    463,
#    492,
#    502,
#    555,
#    583,
#    586,
#    623,
#    645,
#    669,
#    789,
#    824,
#    844,
#    849,
#    923,
#    947,
#    960,
#    975,
#    1170,
#    1232,
#    1234,
#    1240,
#    1254,
#    1271,
#    1286,
#    1299,
#    1373,
#    1468,
#    1550,
#    1684,
#    1687,
#    1761,
#    1810,
#    1817,
#    1877,
#    1885,
#    2042,
#    2053,
#    2057,
#    2065,
#    2067,
#    2101,
#    2127,
#    2210,
#    2242,
#    2365,
#    2397,
#    2443,
#    2461,
#    2529,
#    2708,
#    2859,
#    2897,
#    2911,
#    2940,
#    2945,
#    2977,
#    2994,
#    3002,
#    3066,
#    3115,
#    3120,
#          4279, 4418, 4481, 4733, 4738, 4757, 4969, 4993, 5015, 5110, 5183,
#          5186, 5345, 5351, 5376, 5441, 5595, 5643, 5679, 5813, 5821, 5826,
#          5978, 6075, 6078, 6112, 6188, 6215, 6342, 6403, 6579, 6615, 6624,
#          6719, 6788, 6802, 6843, 6856, 7201, 7233, 7311, 7337, 7396, 7547,
#          7551, 7597, 7690, 7811, 7886, 8065, 8122, 8129, 8261, 8300, 8402,
#          8466, 8524, 8548, 8605, 8608, 8690]),
#   'no_samples': 226,
#   'bounds': {'feature_0': (np.float64(-0.2660436630249023),
#     np.float64(0.7987112998962402)),
#    'feature_1': (np.float64(-0.7441964149475098),
#     np.float64(-0.3409810066223144))}}]

# %%
len(COF_model)
# Out:
# 1

# %%
constraints_on_leaves = get_feature_bounds_from_COF(COF_model)

# %%
high_h = get_h_from_COF(COF_model, greater_then= 1)
high_h
# Out:
# [2.3358495465642157,
#  6.401459401470405,
#  8.856544282965023,
#  1.3102764249261871,
#  4.058125658872891,
#  5.48017675272217,
#  7.976992881504814,
#  7.7558770343066845,
#  2.33576318726724,
#  2.438149783979728,
#  1.7834954335979425,
#  1.1689565347365947,
#  3.3519714372404406,
#  1.1902964284238906,
#  3.0468206592791613,
#  1.790857861507377,
#  1.9686439089633996,
#  1.648850032892773,
#  2.500528756964233,
#  1.0601470381418516,
#  5.152810615478651,
#  1.4765730327967377,
#  1.977888359054111,
#  1.9810801208818194,
#  1.4352632213396839,
#  1.5470871544541493,
#  1.4245731258260275,
#  2.066862192094619,
#  1.84266639032782,
#  1.2175944993636598,
#  2.302638149702546,
#  1.1855165401714511,
#  1.0993899675283811,
#  9.566766112797573,
#  5.7163571287356865,
#  4.210530594890318,
#  6.8223434610032125,
#  2.107631570123387,
#  5.0299485939750825,
#  1.4006955129322545,
#  5.055356229351448]

# %% [markdown]
# # Custom

# %%
import numpy as np
from typing import Optional, List

class _Node:
    def __init__(self, depth: int = 0):
        self.depth = depth
        self.is_leaf = True
        self.feature: Optional[int] = None
        self.threshold: Optional[float] = None
        self.left: Optional[int] = None
        self.right: Optional[int] = None
        self.n_samples: int = 0
        self.value: Optional[np.ndarray] = None
        self.mse: float = 0.0
        self.idx: Optional[np.ndarray] = None  # keep track of samples reaching this node
        self.leaf_id: Optional[int] = None     # assign after pruning

class CustomDecisionTreeRegressor:
    def __init__(
        self,
        max_depth: Optional[int] = None,
        min_samples_split: int = 2,
        mse_threshold: float = 1e-7,
        min_improvement: float = 1e-7,
    ):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.mse_threshold = mse_threshold
        self.min_improvement = min_improvement

        self.n_features_in_: Optional[int] = None
        self.n_outputs_: Optional[int] = None
        self._nodes: List[_Node] = []

    @staticmethod
    def _mse(sum_y: np.ndarray, sum_y2: float, n: int) -> float:
        if n <= 0:
            return 0.0
        return float((sum_y2 - float(np.sum(sum_y ** 2)) / n) / n)

    def fit(self, X: np.ndarray, y: np.ndarray):
        X = np.asarray(X)
        y = np.asarray(y)
        if y.ndim == 1:
            y = y.reshape(-1, 1)
        self.n_features_in_ = X.shape[1]
        self.n_outputs_ = y.shape[1]
        self._nodes = []
        self._build_node(X, y, np.arange(X.shape[0]), depth=0)
        self._assign_leaf_ids()
        self._fitted_X = X
        self._fitted_y = y
        return self

    def _build_node(self, X, y, idx, depth):
        node_id = len(self._nodes)
        node = _Node(depth=depth)
        self._nodes.append(node)

        Y = y[idx]
        n_node = Y.shape[0]
        sum_y = Y.sum(axis=0)
        sum_y2 = float((Y ** 2).sum())

        node.n_samples = n_node
        node.value = sum_y / max(n_node, 1)
        node.mse = self._mse(sum_y, sum_y2, n_node)
        node.idx = idx

        stop_by_depth = (self.max_depth is not None and depth >= self.max_depth)
        if n_node < self.min_samples_split or stop_by_depth or node.mse <= self.mse_threshold:
            node.is_leaf = True
            return node_id

        best = self._best_split(X, y, idx, sum_y, sum_y2, n_node)
        if best is None:
            node.is_leaf = True
            return node_id

        feat, thr, left_idx, right_idx, mse_left, mse_right = best
        parent_mse = node.mse
        n_left, n_right = left_idx.size, right_idx.size
        weighted_child_mse = (n_left * mse_left + n_right * mse_right) / n_node
        gain = parent_mse - weighted_child_mse

        if gain <= self.min_improvement:
            node.is_leaf = True
            return node_id

        node.is_leaf = False
        node.feature = int(feat)
        node.threshold = float(thr)
        node.left = self._build_node(X, y, left_idx, depth + 1)
        node.right = self._build_node(X, y, right_idx, depth + 1)
        return node_id

    def _best_split(self, X, y, idx, sum_y, sum_y2, n_node):
        X_node = X[idx]
        Y_node = y[idx]
        total_sum_y = sum_y
        total_sum_y2 = sum_y2
        parent_mse = self._mse(total_sum_y, total_sum_y2, n_node)

        best_feat = None
        best_thr = None
        best_left_idx = None
        best_right_idx = None
        best_mse_left = None
        best_mse_right = None

        for f in range(self.n_features_in_):
            x = X_node[:, f]
            order = np.argsort(x, kind="mergesort")
            x_sorted = x[order]
            Y_sorted = Y_node[order]

            diffs = x_sorted[1:] - x_sorted[:-1]
            valid = diffs != 0.0
            if not np.any(valid):
                continue

            csum_y = np.cumsum(Y_sorted, axis=0)
            row_sq = np.einsum("ij,ij->i", Y_sorted, Y_sorted)
            csum_y2 = np.cumsum(row_sq)
            split_positions = np.nonzero(valid)[0]

            left_n = (split_positions + 1).astype(np.int64)
            right_n = n_node - left_n
            left_sum_y = csum_y[split_positions]
            right_sum_y = total_sum_y - left_sum_y
            left_sum_y2 = csum_y2[split_positions]
            right_sum_y2 = total_sum_y2 - left_sum_y2

            left_mse = (left_sum_y2 - np.sum(left_sum_y ** 2, axis=1) / left_n) / left_n
            right_mse = (right_sum_y2 - np.sum(right_sum_y ** 2, axis=1) / right_n) / right_n
            weighted_child_mse = (left_n * left_mse + right_n * right_mse) / n_node

            best_pos = int(np.argmin(weighted_child_mse))
            candidate_mse = float(weighted_child_mse[best_pos])
            if candidate_mse >= parent_mse:
                continue

            i = split_positions[best_pos]
            thr = 0.5 * (x_sorted[i] + x_sorted[i + 1])
            mask_left = x <= thr
            left_idx = idx[mask_left]
            right_idx = idx[~mask_left]
            if left_idx.size == 0 or right_idx.size == 0:
                continue

            if best_thr is None or candidate_mse < (best_mse_left + best_mse_right if best_mse_left is not None else np.inf):
                best_feat = f
                best_thr = thr
                best_mse_left = float(left_mse[best_pos])
                best_mse_right = float(right_mse[best_pos])
                best_left_idx = left_idx
                best_right_idx = right_idx

        if best_thr is None:
            return None
        return best_feat, best_thr, best_left_idx, best_right_idx, best_mse_left, best_mse_right

    # --------------------
    # Least squares & pruning by h
    # --------------------
    def _least_squares_solution(self, X_leaf, y_leaf):
        n_samples, n_features = X_leaf.shape
        X_aug = np.hstack([np.ones((n_samples, 1)), X_leaf])
        XtX = X_aug.T @ X_aug
        XtY = X_aug.T @ y_leaf
        Theta = np.linalg.pinv(XtX) @ XtY
        m0 = Theta[0, :]
        M = Theta[1:, :].T
        Y_hat = X_aug @ Theta
        residuals = y_leaf - Y_hat
        h_val = np.sum(residuals ** 2)
        return M, m0, h_val

    def prune_by_h(self, X: np.ndarray, y: np.ndarray, h_threshold: float):
        """
        Post-pruning: collapse children into parent if combined h-value <= threshold.
        """
    
        def _compute_h(idx: np.ndarray) -> float:
            _, _, h_val = self._least_squares_solution(X[idx], y[idx])
            return h_val
    
        def _prune_recursive(node_id: int, idx: np.ndarray):
            node = self._nodes[node_id]
    
            if node.is_leaf:
                return idx
    
            # Split indices
            left_mask = X[idx, node.feature] <= node.threshold
            left_idx = idx[left_mask]
            right_idx = idx[~left_mask]
    
            # Recurse
            left_idx = _prune_recursive(node.left, left_idx)
            right_idx = _prune_recursive(node.right, right_idx)
    
            # Compute combined h
            combined_idx = np.concatenate([left_idx, right_idx])
            combined_h = _compute_h(combined_idx)
    
            # If small enough, prune children (make parent leaf)
            if combined_h <= h_threshold:
                node.is_leaf = True
                node.left = None
                node.right = None
                node.feature = None
                node.threshold = None
                node.value = y[combined_idx].mean(axis=0)
                return combined_idx
    
            return combined_idx
    
        # Start recursion from root
        all_idx = np.arange(X.shape[0])
        _prune_recursive(0, all_idx)

    # --------------------
    # Assign leaf IDs
    # --------------------
    def _assign_leaf_ids(self):
        counter = 0
        for node in self._nodes:
            if node.is_leaf:
                node.leaf_id = counter
                counter += 1

    # --------------------
    # Prediction
    # --------------------
    def predict_row(self, x):
        node_id = 0
        while not self._nodes[node_id].is_leaf:
            node = self._nodes[node_id]
            if x[node.feature] <= node.threshold:
                node_id = node.left
            else:
                node_id = node.right
        return self._nodes[node_id].value

    def predict(self, X):
        X = np.asarray(X)
        return np.vstack([self.predict_row(row) for row in X])

# %%
# 2. Fit the custom decision tree
tree = CustomDecisionTreeRegressor(min_samples_split=2)
tree.fit(X_train, y_train)

print("Number of nodes before pruning:", sum(node.is_leaf for node in tree._nodes))

# 3. Apply pruning based on h_threshold
tree.prune_by_h(X_train, y_train, h_threshold=0.1)

print("Number of nodes after pruning:", sum(node.is_leaf for node in tree._nodes))

# 4. Make predictions
X_test = np.array([[0.2, 0.8], [0.5, 0.5]])
y_pred = tree.predict(X_test)
print("Predictions:", y_pred)
# Out:
# Number of nodes before pruning: 8932
# Number of nodes after pruning: 17762
# Predictions: [[ 0.30241318 -0.16595536]
#  [-0.32021594 -0.48623573]]
