# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor, plot_tree


from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import itertools

from QuadraticConstraintModel import train_COF_on_leaves, get_h_from_COF

from QuadraticConstraintModel import get_feature_bounds_from_COF, predict_from_COF, get_elevated_vertices

from Helping_Code.HelpingFunctions import load_dataset, normalized_root_mean_square_error
from Helping_Code.CustomHyperrectangle import CustomHyperrectangle
from Helping_Code.plot.CustomPlotClass import CustomPlotClass



data_Directory = "Dataset/"

X,y = load_dataset(data_Directory + "SteamGovernor/data_SteamGovernor_10000000.csv",num_attributes = 3, num_classes = 3 )
print(f"Size of the Data Set\n Shape of X = {X.shape} \n Shape of y = {y.shape}")

X_train, X_test, y_train, y_test = train_test_split(X, y,  test_size=0.1)
print(f" Shape of X_Training = {X_train.shape} \n Shape of X_Testing = {X_test.shape}")

# X_train = X
# y_train = y
# Out:
# Size of the Data Set
#  Shape of X = (10000000, 3)
#  Shape of y = (10000000, 3)
#  Shape of X_Training = (9000000, 3)
#  Shape of X_Testing = (1000000, 3)

# %%
from Helping_Code.Optimizers.COFLeafOptimizer import COFLeafOptimizer

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=3, include_bias=False)

# %%
X_train_poly = poly.fit_transform(X_train)
X_train_poly[:2]
# Out:
# array([[ 0.63378894, -0.9446858 ,  0.2744053 ,  0.40168842, -0.59873141,
#          0.17391504,  0.89243126, -0.25922679,  0.07529827,  0.25458568,
#         -0.37946935,  0.11022543,  0.56561306, -0.16429507,  0.04772321,
#         -0.84306714,  0.24488787, -0.07113321,  0.02066224],
#        [ 0.773327  , -0.7954329 ,  0.32454443,  0.59803465, -0.61512974,
#          0.25097897,  0.6327135 , -0.25815332,  0.10532909,  0.46247634,
#         -0.47569644,  0.19408881,  0.48929443, -0.19963693,  0.08145383,
#         -0.50328113,  0.20534364, -0.08378222,  0.03418397]])

# %%
X_test_poly = poly.transform(X_test)
X_test_poly[:2]
# Out:
# array([[-0.11777723, -0.6516137 , -0.12528431,  0.01387148,  0.07674526,
#          0.01475564,  0.42460041,  0.08163697,  0.01569616, -0.00163374,
#         -0.00903884, -0.00173788, -0.05000826, -0.00961498, -0.00184865,
#         -0.27667545, -0.05319577, -0.01022783, -0.00196648],
#        [ 0.8685726 ,  0.6736992 , -0.7164793 ,  0.75441836,  0.58515667,
#         -0.62231429,  0.45387061, -0.48269153,  0.51334259,  0.65526712,
#          0.50825105, -0.54052514,  0.39421958, -0.41925264,  0.44587531,
#          0.30577227, -0.3251889 ,  0.34583849, -0.36779934]])

# %%
from sklearn.preprocessing import StandardScaler

# %%
# --- StandardScaler for X ---
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train_poly)   # fit+transform on training
X_test_scaled = scaler_X.transform(X_test_poly)         # transform only on test

# --- StandardScaler for y ---
scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train)   # fit+transform on training
y_test_scaled = scaler_y.transform(y_test)         # transform only on test

# %%
X_test_scaled[:2]
# Out:
# array([[-0.18579939, -1.02608892, -0.19820678, -1.07962968,  0.19053822,
#          0.03676098,  0.05953098,  0.20243792, -1.07426247, -0.00325345,
#         -0.02619224, -0.00577821, -0.14577419, -0.03767171, -0.0054104 ,
#         -0.54984493, -0.15506178, -0.02958341, -0.00471408],
#        [ 1.36723168,  1.06128666, -1.12907696,  0.97306098,  1.45159622,
#         -1.54293642,  0.14065529, -1.19684656,  0.30480514,  1.30241973,
#          1.47981035, -1.5739783 ,  1.14749816, -1.63783777,  1.29737245,
#          0.60813966, -0.94651931,  1.00648779, -0.73170326]])

# %%
tree = DecisionTreeRegressor(random_state=42, min_samples_leaf=1000000)
tree.fit(X_train_scaled, y_train_scaled)

# %%
cof_model = COFLeafOptimizer(
            tree=tree,
            optimizer="gurobi",
            h_max=2.0,
            random_state=42,
            scaler_X=scaler_X,
            n_jobs=5
        )

# %%
cof_model.fit(X_train_scaled, y_train_scaled)
# Out:
# Optimization on Leaf ID = 648
# Restricted license - for non-production use only - expires 2026-11-23
# Optimization on Leaf ID = 588
# Restricted license - for non-production use only - expires 2026-11-23
# Optimization on Leaf ID = 217
# Restricted license - for non-production use only - expires 2026-11-23
# Optimization on Leaf ID = 652
# Restricted license - for non-production use only - expires 2026-11-23
# Optimization on Leaf ID = 568
# Restricted license - for non-production use only - expires 2026-11-23
# COFLeafOptimizer(n_jobs=5, optimizer='gurobi',
#                  random_state=RandomState(MT19937) at 0x724CE5BD7740,
#                  scaler_X=StandardScaler(),
#                  tree=DecisionTreeRegressor(min_samples_leaf=10000,
#                                             random_state=42))

# %%
print("Number of modeled leaves:", len(cof_model.leaf_models))
for lid, leaf in list(cof_model.leaf_models.items()):
    print("H = ", leaf.h)
# Out:
# Number of modeled leaves: 671
# H =  3.418398572601158e-06
# H =  0.024720795188590383
# H =  inf
# H =  inf
# H =  inf
# H =  5.59077589657083e-05
# H =  inf
# H =  0.00018359850871866104
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =  4.1101195868828255e-05
# H =  7.133355950353925e-06
# H =  4.946556221732556e-05
# H =  inf
# H =  inf
# H =  4.2350738038259236e-05
# H =  inf
# H =  2.3012077047434095e-07
# H =  4.197914527974021e-05
# H =  3.368309142423639e-05
# H =  inf
# H =  inf
# H =  0.0036643289353173007
# H =  inf
# H =  inf
# H =  6.994449661361715e-06
# H =  inf
# H =  1.803864438583488e-05
# H =  5.7803318464064895e-05
# H =  inf
# H =  inf
# H =  2.372460110698543e-06
# H =  inf
# H =  9.884858348374305e-06
# H =  4.784408891167846e-05
# H =  0.0025475931227910698
# H =  2.3146470326172914e-05
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =  0.0005005842070020337
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =  1.9430873103336437e-06
# H =  inf
# H =  inf
# H =  9.524855004703118e-08
# H =  inf
# H =  0.000269410454508223
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =  1.7566608933025044e-05
# H =  inf
# H =  inf
# H =  inf
# H =  6.6714303192636176e-06
# H =  inf
# H =  inf
# H =  inf
# H =  2.594455193967308e-07
# H =  2.0168461486318346e-07
# H =  7.888676505296344e-08
# H =  inf
# H =  1.6996596120309864e-05
# H =  inf
# H =  1.2640862533269903e-05
# H =  inf
# H =  inf
# H =  4.51035420764821e-06
# H =  inf
# H =  inf
# H =  inf
# H =  1.3331419361053309e-05
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =  3.4317928535512128e-06
# H =  inf
# H =  inf
# H =  1.9354138836904763e-07
# H =  0.001241439302612279
# H =  inf
# H =  inf
# H =  inf
# H =  1.0562372998201003e-06
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =  inf
# H =  3.3468528738760063e-07
# H =  5.623004967658745e-06
# H =  inf
# Optimization on Leaf ID = 866
# Optimization on Leaf ID = 1041
# Optimization on Leaf ID = 822
# Optimization on Leaf ID = 550
# Optimization on Leaf ID = 729
# Optimization on Leaf ID = 1145
# Optimization on Leaf ID = 1134
# Optimization on Leaf ID = 787
# Optimization on Leaf ID = 248
# Optimization on Leaf ID = 1155
# Optimization on Leaf ID = 970
# Optimization on Leaf ID = 244
# Optimization on Leaf ID = 1203
# Optimization on Leaf ID = 432
# Optimization on Leaf ID = 135
# Optimization on Leaf ID = 981
# Optimization on Leaf ID = 1285
# Optimization on Leaf ID = 913
# Optimization on Leaf ID = 869
# Optimization on Leaf ID = 613
# Optimization on Leaf ID = 903
# Optimization on Leaf ID = 906
# Optimization on Leaf ID = 985
# Optimization on Leaf ID = 489
# Optimization on Leaf ID = 241
# Optimization on Leaf ID = 1022
# Optimization on Leaf ID = 544
# Optimization on Leaf ID = 106
# Optimization on Leaf ID = 74
# Optimization on Leaf ID = 53
# Optimization on Leaf ID = 595
# Optimization on Leaf ID = 52
# Optimization on Leaf ID = 577
# Optimization on Leaf ID = 1169
# Optimization on Leaf ID = 140
# Optimization on Leaf ID = 371
# Optimization on Leaf ID = 1069
# Optimization on Leaf ID = 226
# Optimization on Leaf ID = 937
# Optimization on Leaf ID = 166
# Optimization on Leaf ID = 797
# Optimization on Leaf ID = 1135
# Optimization on Leaf ID = 314
# Optimization on Leaf ID = 581
# Optimization on Leaf ID = 539
# Optimization on Leaf ID = 1160
# Optimization on Leaf ID = 655
# Optimization on Leaf ID = 825
# Optimization on Leaf ID = 661
# Optimization on Leaf ID = 671
# Optimization on Leaf ID = 29
# Optimization on Leaf ID = 1081
# Optimization on Leaf ID = 187
# Optimization on Leaf ID = 547
# Optimization on Leaf ID = 917
# Optimization on Leaf ID = 1302
# Optimization on Leaf ID = 1325
# Optimization on Leaf ID = 765
# Optimization on Leaf ID = 320
# Optimization on Leaf ID = 1244
# Optimization on Leaf ID = 860
# Optimization on Leaf ID = 300
# Optimization on Leaf ID = 553
# Optimization on Leaf ID = 264
# Optimization on Leaf ID = 803
# Optimization on Leaf ID = 1126
# Optimization on Leaf ID = 1278
# Optimization on Leaf ID = 865
# Optimization on Leaf ID = 948
# Optimization on Leaf ID = 780
# Optimization on Leaf ID = 743
# Optimization on Leaf ID = 395
# Optimization on Leaf ID = 1048
# Optimization on Leaf ID = 1099
# Optimization on Leaf ID = 484
# Optimization on Leaf ID = 1277
# Optimization on Leaf ID = 916
# Optimization on Leaf ID = 146
# Optimization on Leaf ID = 480
# Optimization on Leaf ID = 723
# Optimization on Leaf ID = 35
# Optimization on Leaf ID = 751
# Optimization on Leaf ID = 253
# Optimization on Leaf ID = 1068
# Optimization on Leaf ID = 1269
# Optimization on Leaf ID = 99
# Optimization on Leaf ID = 567
# Optimization on Leaf ID = 1032
# Optimization on Leaf ID = 284
# Optimization on Leaf ID = 878
# Optimization on Leaf ID = 171
# Optimization on Leaf ID = 554
# Optimization on Leaf ID = 600
# Optimization on Leaf ID = 828
# Optimization on Leaf ID = 254
# Optimization on Leaf ID = 886
# Optimization on Leaf ID = 1034
# Optimization on Leaf ID = 732
# Optimization on Leaf ID = 1044
# Optimization on Leaf ID = 155
# Optimization on Leaf ID = 359
# Optimization on Leaf ID = 1124
# Optimization on Leaf ID = 1123
# Optimization on Leaf ID = 49
# Optimization on Leaf ID = 156
# Optimization on Leaf ID = 100
# Optimization on Leaf ID = 697
# Optimization on Leaf ID = 124
# Optimization on Leaf ID = 1243
# Optimization on Leaf ID = 688
# Optimization on Leaf ID = 1217
# Optimization on Leaf ID = 693
# Optimization on Leaf ID = 1197
# Optimization on Leaf ID = 1295
# Optimization on Leaf ID = 276
# Optimization on Leaf ID = 849
# Optimization on Leaf ID = 1082
# Optimization on Leaf ID = 1092
# Optimization on Leaf ID = 718
# Optimization on Leaf ID = 465
# Optimization on Leaf ID = 768
# Optimization on Leaf ID = 982
# Optimization on Leaf ID = 319
# Optimization on Leaf ID = 163
# Optimization on Leaf ID = 1071
# Optimization on Leaf ID = 435
# Optimization on Leaf ID = 1062
# Optimization on Leaf ID = 312
# Optimization on Leaf ID = 843
# Optimization on Leaf ID = 1148
# Optimization on Leaf ID = 381
# Optimization on Leaf ID = 105
# Optimization on Leaf ID = 923
# Optimization on Leaf ID = 261
# Optimization on Leaf ID = 1248
# Optimization on Leaf ID = 210
# Optimization on Leaf ID = 859
# Optimization on Leaf ID = 1293
# Optimization on Leaf ID = 57
# Optimization on Leaf ID = 297
# Optimization on Leaf ID = 1166
# Optimization on Leaf ID = 1339
# Optimization on Leaf ID = 622
# Optimization on Leaf ID = 111
# Optimization on Leaf ID = 474
# Optimization on Leaf ID = 516
# Optimization on Leaf ID = 179
# Optimization on Leaf ID = 483
# Optimization on Leaf ID = 1270
# Optimization on Leaf ID = 934
# Optimization on Leaf ID = 663
# Optimization on Leaf ID = 94
# Optimization on Leaf ID = 353
# Optimization on Leaf ID = 625
# Optimization on Leaf ID = 47
# Optimization on Leaf ID = 1307
# Optimization on Leaf ID = 778
# Optimization on Leaf ID = 615
# Optimization on Leaf ID = 1140
# Optimization on Leaf ID = 160
# Optimization on Leaf ID = 361
# Optimization on Leaf ID = 202
# Optimization on Leaf ID = 360
# Optimization on Leaf ID = 433
# Optimization on Leaf ID = 1177
# Optimization on Leaf ID = 1008
# Optimization on Leaf ID = 920
# Optimization on Leaf ID = 1100
# Optimization on Leaf ID = 182
# Optimization on Leaf ID = 393
# Optimization on Leaf ID = 506
# Optimization on Leaf ID = 1005
# Optimization on Leaf ID = 598
# Optimization on Leaf ID = 496
# Optimization on Leaf ID = 138
# Optimization on Leaf ID = 1306
# Optimization on Leaf ID = 249
# Optimization on Leaf ID = 17
# Optimization on Leaf ID = 1210
# Optimization on Leaf ID = 290
# Optimization on Leaf ID = 704
# Optimization on Leaf ID = 685
# Optimization on Leaf ID = 283
# Optimization on Leaf ID = 129
# Optimization on Leaf ID = 25
# Optimization on Leaf ID = 1260
# Optimization on Leaf ID = 1019
# Optimization on Leaf ID = 656
# Optimization on Leaf ID = 779
# Optimization on Leaf ID = 409
# Optimization on Leaf ID = 198
# Optimization on Leaf ID = 214
# Optimization on Leaf ID = 230
# Optimization on Leaf ID = 152
# Optimization on Leaf ID = 60
# Optimization on Leaf ID = 1078
# Optimization on Leaf ID = 814
# Optimization on Leaf ID = 793
# Optimization on Leaf ID = 800
# Optimization on Leaf ID = 520
# Optimization on Leaf ID = 466
# Optimization on Leaf ID = 935
# Optimization on Leaf ID = 699
# Optimization on Leaf ID = 326
# Optimization on Leaf ID = 1184
# Optimization on Leaf ID = 50
# Optimization on Leaf ID = 1033
# Optimization on Leaf ID = 1045
# Optimization on Leaf ID = 325
# Optimization on Leaf ID = 829
# Optimization on Leaf ID = 368
# Optimization on Leaf ID = 418
# Optimization on Leaf ID = 199
# Optimization on Leaf ID = 1336
# Optimization on Leaf ID = 336
# Optimization on Leaf ID = 973
# Optimization on Leaf ID = 39
# Optimization on Leaf ID = 514
# Optimization on Leaf ID = 1224
# Optimization on Leaf ID = 1042
# Optimization on Leaf ID = 1206
# Optimization on Leaf ID = 1266
# Optimization on Leaf ID = 1317
# Optimization on Leaf ID = 1332
# Optimization on Leaf ID = 332
# Optimization on Leaf ID = 134
# Optimization on Leaf ID = 1051
# Optimization on Leaf ID = 1152
# Optimization on Leaf ID = 638
# Optimization on Leaf ID = 449
# Optimization on Leaf ID = 23
# Optimization on Leaf ID = 1251
# Optimization on Leaf ID = 1096
# Optimization on Leaf ID = 145
# Optimization on Leaf ID = 1151
# Optimization on Leaf ID = 455
# Optimization on Leaf ID = 902
# Optimization on Leaf ID = 495
# Optimization on Leaf ID = 1187
# Optimization on Leaf ID = 408
# Optimization on Leaf ID = 815
# Optimization on Leaf ID = 46
# Optimization on Leaf ID = 415
# Optimization on Leaf ID = 709
# Optimization on Leaf ID = 86
# Optimization on Leaf ID = 606
# Optimization on Leaf ID = 833
# Optimization on Leaf ID = 399
# Optimization on Leaf ID = 1104
# Optimization on Leaf ID = 426
# Optimization on Leaf ID = 128
# Optimization on Leaf ID = 910
# Optimization on Leaf ID = 1284
# Optimization on Leaf ID = 82
# Optimization on Leaf ID = 423
# Optimization on Leaf ID = 601
# Optimization on Leaf ID = 75
# Optimization on Leaf ID = 741
# Optimization on Leaf ID = 448
# Optimization on Leaf ID = 265
# Optimization on Leaf ID = 1207
# Optimization on Leaf ID = 640
# Optimization on Leaf ID = 1340
# Optimization on Leaf ID = 11
# Optimization on Leaf ID = 1310
# Optimization on Leaf ID = 571
# Optimization on Leaf ID = 1324
# Optimization on Leaf ID = 1321
# Optimization on Leaf ID = 120
# Optimization on Leaf ID = 1088
# Optimization on Leaf ID = 1120
# Optimization on Leaf ID = 773
# Optimization on Leaf ID = 711
# Optimization on Leaf ID = 683
# Optimization on Leaf ID = 1138
# Optimization on Leaf ID = 38
# Optimization on Leaf ID = 1215
# Optimization on Leaf ID = 804
# Optimization on Leaf ID = 1163
# Optimization on Leaf ID = 508
# Optimization on Leaf ID = 889
# Optimization on Leaf ID = 987
# Optimization on Leaf ID = 255
# Optimization on Leaf ID = 1117
# Optimization on Leaf ID = 628
# Optimization on Leaf ID = 344
# Optimization on Leaf ID = 1200
# Optimization on Leaf ID = 997
# Optimization on Leaf ID = 801
# Optimization on Leaf ID = 1091
# Optimization on Leaf ID = 1132
# Optimization on Leaf ID = 1052
# Optimization on Leaf ID = 563
# Optimization on Leaf ID = 311
# Optimization on Leaf ID = 999
# Optimization on Leaf ID = 546
# Optimization on Leaf ID = 1236
# Optimization on Leaf ID = 832
# Optimization on Leaf ID = 1241
# Optimization on Leaf ID = 1330
# Optimization on Leaf ID = 853
# Optimization on Leaf ID = 928
# Optimization on Leaf ID = 201
# Optimization on Leaf ID = 842
# Optimization on Leaf ID = 823
# Optimization on Leaf ID = 879
# Optimization on Leaf ID = 689
# Optimization on Leaf ID = 1009
# Optimization on Leaf ID = 164
# Optimization on Leaf ID = 637
# Optimization on Leaf ID = 532
# Optimization on Leaf ID = 1202
# Optimization on Leaf ID = 724
# Optimization on Leaf ID = 469
# Optimization on Leaf ID = 1144
# Optimization on Leaf ID = 268
# Optimization on Leaf ID = 473
# Optimization on Leaf ID = 1006
# Optimization on Leaf ID = 584
# Optimization on Leaf ID = 887
# Optimization on Leaf ID = 1292
# Optimization on Leaf ID = 956
# Optimization on Leaf ID = 273
# Optimization on Leaf ID = 278
# Optimization on Leaf ID = 428
# Optimization on Leaf ID = 227
# Optimization on Leaf ID = 461
# Optimization on Leaf ID = 1333
# Optimization on Leaf ID = 194
# Optimization on Leaf ID = 272
# Optimization on Leaf ID = 1097
# Optimization on Leaf ID = 1282
# Optimization on Leaf ID = 110
# Optimization on Leaf ID = 644
# Optimization on Leaf ID = 1060
# Optimization on Leaf ID = 131
# Optimization on Leaf ID = 717
# Optimization on Leaf ID = 769
# Optimization on Leaf ID = 476
# Optimization on Leaf ID = 686
# Optimization on Leaf ID = 1225
# Optimization on Leaf ID = 1249
# Optimization on Leaf ID = 758
# Optimization on Leaf ID = 237
# Optimization on Leaf ID = 700
# Optimization on Leaf ID = 957
# Optimization on Leaf ID = 757
# Optimization on Leaf ID = 766
# Optimization on Leaf ID = 28
# Optimization on Leaf ID = 1072
# Optimization on Leaf ID = 1027
# Optimization on Leaf ID = 538
# Optimization on Leaf ID = 1259
# Optimization on Leaf ID = 846
# Optimization on Leaf ID = 335
# Optimization on Leaf ID = 873
# Optimization on Leaf ID = 178
# Optimization on Leaf ID = 517
# Optimization on Leaf ID = 175
# Optimization on Leaf ID = 97
# Optimization on Leaf ID = 668
# Optimization on Leaf ID = 425
# Optimization on Leaf ID = 1318
# Optimization on Leaf ID = 963
# Optimization on Leaf ID = 396
# Optimization on Leaf ID = 754
# Optimization on Leaf ID = 738
# Optimization on Leaf ID = 68
# Optimization on Leaf ID = 356
# Optimization on Leaf ID = 1234
# Optimization on Leaf ID = 70
# Optimization on Leaf ID = 728
# Optimization on Leaf ID = 144
# Optimization on Leaf ID = 1016
# Optimization on Leaf ID = 355
# Optimization on Leaf ID = 279
# Optimization on Leaf ID = 1314
# Optimization on Leaf ID = 321
# Optimization on Leaf ID = 238
# Optimization on Leaf ID = 774
# Optimization on Leaf ID = 499
# Optimization on Leaf ID = 61
# Optimization on Leaf ID = 528
# Optimization on Leaf ID = 1106
# Optimization on Leaf ID = 446
# Optimization on Leaf ID = 786
# Optimization on Leaf ID = 378
# Optimization on Leaf ID = 1127
# Optimization on Leaf ID = 367
# Optimization on Leaf ID = 962
# Optimization on Leaf ID = 596
# Optimization on Leaf ID = 961
# Optimization on Leaf ID = 977
# Optimization on Leaf ID = 1255
# Optimization on Leaf ID = 762
# Optimization on Leaf ID = 123
# Optimization on Leaf ID = 752
# Optimization on Leaf ID = 1023
# Optimization on Leaf ID = 232
# Optimization on Leaf ID = 938
# Optimization on Leaf ID = 949
# Optimization on Leaf ID = 1181
# Optimization on Leaf ID = 608
# Optimization on Leaf ID = 863
# Optimization on Leaf ID = 900
# Optimization on Leaf ID = 587
# Optimization on Leaf ID = 720
# Optimization on Leaf ID = 561
# Optimization on Leaf ID = 32
# Optimization on Leaf ID = 40
# Optimization on Leaf ID = 946
# Optimization on Leaf ID = 83
# Optimization on Leaf ID = 181
# Optimization on Leaf ID = 275
# Optimization on Leaf ID = 570
# Optimization on Leaf ID = 940
# Optimization on Leaf ID = 1011
# Optimization on Leaf ID = 481
# Optimization on Leaf ID = 1267
# Optimization on Leaf ID = 971
# Optimization on Leaf ID = 1116
# Optimization on Leaf ID = 513
# Optimization on Leaf ID = 1064
# Optimization on Leaf ID = 452
# Optimization on Leaf ID = 735
# Optimization on Leaf ID = 338
# Optimization on Leaf ID = 491
# Optimization on Leaf ID = 1303
# Optimization on Leaf ID = 592
# Optimization on Leaf ID = 213
# Optimization on Leaf ID = 1055
# Optimization on Leaf ID = 315
# Optimization on Leaf ID = 405
# Optimization on Leaf ID = 333
# Optimization on Leaf ID = 262
# Optimization on Leaf ID = 531
# Optimization on Leaf ID = 167
# Optimization on Leaf ID = 789
# Optimization on Leaf ID = 1237
# Optimization on Leaf ID = 798
# Optimization on Leaf ID = 347
# Optimization on Leaf ID = 1222
# Optimization on Leaf ID = 755
# Optimization on Leaf ID = 922
# Optimization on Leaf ID = 412
# Optimization on Leaf ID = 285
# Optimization on Leaf ID = 349
# Optimization on Leaf ID = 862
# Optimization on Leaf ID = 911
# Optimization on Leaf ID = 899
# Optimization on Leaf ID = 998
# Optimization on Leaf ID = 386
# Optimization on Leaf ID = 492
# Optimization on Leaf ID = 69
# Optimization on Leaf ID = 945
# Optimization on Leaf ID = 1296
# Optimization on Leaf ID = 1147
# Optimization on Leaf ID = 605
# Optimization on Leaf ID = 303
# Optimization on Leaf ID = 632
# Optimization on Leaf ID = 233
# Optimization on Leaf ID = 301
# Optimization on Leaf ID = 350
# Optimization on Leaf ID = 1085
# Optimization on Leaf ID = 835
# Optimization on Leaf ID = 103
# Optimization on Leaf ID = 521
# Optimization on Leaf ID = 993
# Optimization on Leaf ID = 153
# Optimization on Leaf ID = 1315
# Optimization on Leaf ID = 390
# Optimization on Leaf ID = 1274
# Optimization on Leaf ID = 880
# Optimization on Leaf ID = 12
# Optimization on Leaf ID = 809
# Optimization on Leaf ID = 535
# Optimization on Leaf ID = 1054
# Optimization on Leaf ID = 775
# Optimization on Leaf ID = 1079
# Optimization on Leaf ID = 1020
# Optimization on Leaf ID = 1329
# Optimization on Leaf ID = 731
# Optimization on Leaf ID = 121
# Optimization on Leaf ID = 883
# Optimization on Leaf ID = 890
# Optimization on Leaf ID = 298
# Optimization on Leaf ID = 240
# Optimization on Leaf ID = 468
# Optimization on Leaf ID = 93
# Optimization on Leaf ID = 705
# Optimization on Leaf ID = 660
# Optimization on Leaf ID = 404
# Optimization on Leaf ID = 670
# Optimization on Leaf ID = 505
# Optimization on Leaf ID = 288
# Optimization on Leaf ID = 1170
# Optimization on Leaf ID = 1017
# Optimization on Leaf ID = 379
# Optimization on Leaf ID = 1084
# Optimization on Leaf ID = 109
# Optimization on Leaf ID = 1167
# Optimization on Leaf ID = 1337
# Optimization on Leaf ID = 1139
# Optimization on Leaf ID = 852
# Optimization on Leaf ID = 988
# Optimization on Leaf ID = 992
# Optimization on Leaf ID = 118
# Optimization on Leaf ID = 370
# Optimization on Leaf ID = 1162
# Optimization on Leaf ID = 509
# Optimization on Leaf ID = 826
# Optimization on Leaf ID = 641
# Optimization on Leaf ID = 190
# Optimization on Leaf ID = 64
# Optimization on Leaf ID = 872
# Optimization on Leaf ID = 429
# Optimization on Leaf ID = 411
# Optimization on Leaf ID = 1180
# Optimization on Leaf ID = 174
# Optimization on Leaf ID = 1240
# Optimization on Leaf ID = 1119
# Optimization on Leaf ID = 18
# Optimization on Leaf ID = 951
# Optimization on Leaf ID = 1263
# Optimization on Leaf ID = 159
# Optimization on Leaf ID = 96
# Optimization on Leaf ID = 195
# Optimization on Leaf ID = 267
# Optimization on Leaf ID = 1190
# Optimization on Leaf ID = 308
# Optimization on Leaf ID = 792
# Optimization on Leaf ID = 845
# Optimization on Leaf ID = 1065
# Optimization on Leaf ID = 26
# Optimization on Leaf ID = 15
# Optimization on Leaf ID = 339
# Optimization on Leaf ID = 580
# Optimization on Leaf ID = 1309
# Optimization on Leaf ID = 387
# Optimization on Leaf ID = 1029
# Optimization on Leaf ID = 324
# Optimization on Leaf ID = 243
# Optimization on Leaf ID = 740
# Optimization on Leaf ID = 1281
# Optimization on Leaf ID = 63
# Optimization on Leaf ID = 694
# Optimization on Leaf ID = 1183
# Optimization on Leaf ID = 551
# Optimization on Leaf ID = 382
# Optimization on Leaf ID = 1254
# Optimization on Leaf ID = 1191
# Optimization on Leaf ID = 529
# Optimization on Leaf ID = 250
# Optimization on Leaf ID = 974
# Optimization on Leaf ID = 578
# Optimization on Leaf ID = 1275
# Optimization on Leaf ID = 1199
# Optimization on Leaf ID = 585
# Optimization on Leaf ID = 984
# Optimization on Leaf ID = 459
# Optimization on Leaf ID = 631
# Optimization on Leaf ID = 543
# Optimization on Leaf ID = 629
# Optimization on Leaf ID = 763
# Optimization on Leaf ID = 1233
# Optimization on Leaf ID = 89
# Optimization on Leaf ID = 696
# Optimization on Leaf ID = 941
# Optimization on Leaf ID = 994
# Optimization on Leaf ID = 836
# Optimization on Leaf ID = 216
# Optimization on Leaf ID = 926
# Optimization on Leaf ID = 616
# Optimization on Leaf ID = 645
# Optimization on Leaf ID = 706
# Optimization on Leaf ID = 1218
# Optimization on Leaf ID = 132
# Optimization on Leaf ID = 229
# Optimization on Leaf ID = 870
# Optimization on Leaf ID = 209
# Optimization on Leaf ID = 346
# Optimization on Leaf ID = 958
# Optimization on Leaf ID = 1131
# Optimization on Leaf ID = 1178
# Optimization on Leaf ID = 560
# Optimization on Leaf ID = 453
# Optimization on Leaf ID = 667
# Optimization on Leaf ID = 436
# Optimization on Leaf ID = 609
# Optimization on Leaf ID = 141
# Optimization on Leaf ID = 376
# Optimization on Leaf ID = 624
# Optimization on Leaf ID = 309
# Optimization on Leaf ID = 1221
# Optimization on Leaf ID = 721
# Optimization on Leaf ID = 744
# Optimization on Leaf ID = 882
# Optimization on Leaf ID = 710
# Optimization on Leaf ID = 304
# Optimization on Leaf ID = 682
# Optimization on Leaf ID = 207
# Optimization on Leaf ID = 88
# Optimization on Leaf ID = 1299
# Optimization on Leaf ID = 813
# Optimization on Leaf ID = 172
# Optimization on Leaf ID = 498
# Optimization on Leaf ID = 664
# Optimization on Leaf ID = 462
# Optimization on Leaf ID = 289
# Optimization on Leaf ID = 58
# Optimization on Leaf ID = 188
# Optimization on Leaf ID = 419
# Optimization on Leaf ID = 1262
# Optimization on Leaf ID = 564
# Optimization on Leaf ID = 807
# Optimization on Leaf ID = 536
# Optimization on Leaf ID = 85
# Optimization on Leaf ID = 1107
# Optimization on Leaf ID = 1012
# Optimization on Leaf ID = 734
# Optimization on Leaf ID = 1154
# Optimization on Leaf ID = 1047
# Optimization on Leaf ID = 523
# Optimization on Leaf ID = 790
# Optimization on Leaf ID = 621
# Optimization on Leaf ID = 456
# Optimization on Leaf ID = 416
# Optimization on Leaf ID = 488
# Optimization on Leaf ID = 841
# Optimization on Leaf ID = 1188
# Optimization on Leaf ID = 653
# Optimization on Leaf ID = 810
# Optimization on Leaf ID = 73
# Optimization on Leaf ID = 850
# Optimization on Leaf ID = 1103
# Optimization on Leaf ID = 927
# Optimization on Leaf ID = 593
# Optimization on Leaf ID = 34
# Optimization on Leaf ID = 1300
# Optimization on Leaf ID = 14
# Optimization on Leaf ID = 445
# Optimization on Leaf ID = 1159
# Optimization on Leaf ID = 1322
# Optimization on Leaf ID = 647
# Optimization on Leaf ID = 612
# Optimization on Leaf ID = 1209
# Optimization on Leaf ID = 398
# Optimization on Leaf ID = 1061
# Optimization on Leaf ID = 375
# Optimization on Leaf ID = 1252
# Optimization on Leaf ID = 117
# Optimization on Leaf ID = 477
# Optimization on Leaf ID = 1089
# Optimization on Leaf ID = 914
# Optimization on Leaf ID = 524
# Optimization on Leaf ID = 343
# Optimization on Leaf ID = 389
# Optimization on Leaf ID = 22
# Optimization on Leaf ID = 952
# Optimization on Leaf ID = 905
# Optimization on Leaf ID = 206
# Optimization on Leaf ID = 191
# Optimization on Leaf ID = 976
# Optimization on Leaf ID = 1196
# Optimization on Leaf ID = 1028
# Optimization on Leaf ID = 1214
